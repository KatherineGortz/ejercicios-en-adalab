# %% [markdown]
# 1. Exploración del conjunto de datos:
#
#     - Carga el fichero, al cargarlo te aparecerá una columna llamada "Unnamed: 0". Carga el dataset sin que aparezca esta columna. Además realiza un análisis exploratorio que incluya:
#
#         - Cuando leas el fichero, veras que no podemos ver todas las columnas, utiliza el comando correcto para poder visualizarlas todas cuando hacemos un head
#
#         - Primeras 5 filas del *dataframe*
#
#         - Últimas 5 filas del *dataframe*
#
#         - 10 filas aleatorias del *dataframe*
#
#         - ¿Cuántas filas y columnas tenemos en el *dataframe*
#
#         - ¿Cuáles son los tipos de los datos de cada columna del *dataframe*
#
#         - ¿Cuántos valores nulos tenemos por columna?
#
#         - ¿Tenemos filas duplicadas en el *dataframe* ?
#
#         - Muestra los principales estadísticos para las columnas numéricas del *dataframe*
#
#         - Muestra los principales estadísticos para las columnas categóricas del *dataframe*

# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
#Carga el fichero, al cargarlo te aparecerá una columna llamada "Unnamed: 0". Carga el dataset sin que aparezca esta columna. Además realiza un análisis exploratorio que incluya: 
#Cuando leas el fichero, veras que no podemos ver todas las columnas, utiliza el comando correcto para poder visualizarlas todas cuando hacemos un head

df = pd.read_csv("Spoty.csv", index_col=0)

df.head()
# Out:
#      Artist                                        Url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# 3                                  Plastic Beach      album
# 4                                       Gorillaz      album
#
#                                     Uri  Danceability  Energy   Key  Loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705   6.0    -6.679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703   8.0    -5.815
# 2  spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923   1.0    -3.930
# 3  spotify:track:0q6LuUqGLUiCPP1cbdwFs3         0.689   0.739   2.0    -5.810
# 4  spotify:track:7yMiX7n9SBvadzox8T5jzT         0.663   0.694  10.0    -8.627
#
#    Speechiness  Acousticness  Instrumentalness  Liveness  Valence    Tempo  \
# 0       0.1770      0.008360          0.002330    0.6130    0.772  138.559
# 1       0.0302      0.086900          0.000687    0.0463    0.852   92.761
# 2       0.0522      0.042500          0.046900    0.1160    0.551  108.014
# 3       0.0260      0.000015          0.509000    0.0640    0.578  120.423
# 4       0.1710      0.025300          0.000000    0.0698    0.525  167.953
#
#    Duration_ms                                  Url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1     200173.0  https://www.youtube.com/watch?v=yYDmaexVHic
# 2     215150.0  https://www.youtube.com/watch?v=qJa-VFwPpYA
# 3     233867.0  https://www.youtube.com/watch?v=04mfKJWDSzI
# 4     340920.0  https://www.youtube.com/watch?v=1V_xRb0x9aw
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
# 2  Gorillaz - New Gold ft. Tame Impala & Bootie B...  Gorillaz    8435055.0
# 3     Gorillaz - On Melancholy Hill (Official Video)  Gorillaz  211754952.0
# 4         Gorillaz - Clint Eastwood (Official Video)  Gorillaz  618480958.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
# 2   282142.0    7399.0  Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 3  1788577.0   55229.0  Follow Gorillaz online:\nhttp://gorillaz.com \...
# 4  6197318.0  155930.0  The official music video for Gorillaz - Clint ...
#
#   Licensed official_video        Stream
# 0     True           True  1.040235e+09
# 1     True           True  3.100837e+08
# 2     True           True  6.306347e+07
# 3     True           True  4.346636e+08
# 4     True           True  6.172597e+08

# %%
#Primeras 5 filas del *dataframe*

df.head(5)
# Out:
#      Artist                                        Url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# 3                                  Plastic Beach      album
# 4                                       Gorillaz      album
#
#                                     Uri  Danceability  Energy   Key  Loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705   6.0    -6.679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703   8.0    -5.815
# 2  spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923   1.0    -3.930
# 3  spotify:track:0q6LuUqGLUiCPP1cbdwFs3         0.689   0.739   2.0    -5.810
# 4  spotify:track:7yMiX7n9SBvadzox8T5jzT         0.663   0.694  10.0    -8.627
#
#    Speechiness  Acousticness  Instrumentalness  Liveness  Valence    Tempo  \
# 0       0.1770      0.008360          0.002330    0.6130    0.772  138.559
# 1       0.0302      0.086900          0.000687    0.0463    0.852   92.761
# 2       0.0522      0.042500          0.046900    0.1160    0.551  108.014
# 3       0.0260      0.000015          0.509000    0.0640    0.578  120.423
# 4       0.1710      0.025300          0.000000    0.0698    0.525  167.953
#
#    Duration_ms                                  Url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1     200173.0  https://www.youtube.com/watch?v=yYDmaexVHic
# 2     215150.0  https://www.youtube.com/watch?v=qJa-VFwPpYA
# 3     233867.0  https://www.youtube.com/watch?v=04mfKJWDSzI
# 4     340920.0  https://www.youtube.com/watch?v=1V_xRb0x9aw
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
# 2  Gorillaz - New Gold ft. Tame Impala & Bootie B...  Gorillaz    8435055.0
# 3     Gorillaz - On Melancholy Hill (Official Video)  Gorillaz  211754952.0
# 4         Gorillaz - Clint Eastwood (Official Video)  Gorillaz  618480958.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
# 2   282142.0    7399.0  Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 3  1788577.0   55229.0  Follow Gorillaz online:\nhttp://gorillaz.com \...
# 4  6197318.0  155930.0  The official music video for Gorillaz - Clint ...
#
#   Licensed official_video        Stream
# 0     True           True  1.040235e+09
# 1     True           True  3.100837e+08
# 2     True           True  6.306347e+07
# 3     True           True  4.346636e+08
# 4     True           True  6.172597e+08

# %%
#Últimas 5 filas del *dataframe*

df.tail(5)
# Out:
#             Artist                                        Url_spotify  \
# 20713  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                 Track                           Album  \
# 20713            JUST DANCE HARDSTYLE            JUST DANCE HARDSTYLE
# 20714  SET FIRE TO THE RAIN HARDSTYLE  SET FIRE TO THE RAIN HARDSTYLE
# 20715       OUTSIDE HARDSTYLE SPED UP       OUTSIDE HARDSTYLE SPED UP
# 20716             ONLY GIRL HARDSTYLE             ONLY GIRL HARDSTYLE
# 20717              MISS YOU HARDSTYLE              MISS YOU HARDSTYLE
#
#       Album_type                                   Uri  Danceability  Energy  \
# 20713     single  spotify:track:0RtcKQGyI4hr8FgFH1TuYG         0.582   0.926
# 20714     single  spotify:track:3rHvPA8lUnPBkaLyPOc0VV         0.531   0.936
# 20715     single  spotify:track:4jk00YxPtPbhvHJE9N4ddv         0.443   0.830
# 20716     single  spotify:track:5EyErbpsugWliX006eTDex         0.417   0.767
# 20717     single  spotify:track:6lOn0jz1QpjcWeXo1oMm0k         0.498   0.938
#
#        Key  Loudness  Speechiness  Acousticness  Instrumentalness  Liveness  \
# 20713  5.0    -6.344       0.0328       0.44800            0.0000    0.0839
# 20714  4.0    -1.786       0.1370       0.02800            0.0000    0.0923
# 20715  4.0    -4.679       0.0647       0.02430            0.0000    0.1540
# 20716  9.0    -4.004       0.4190       0.35600            0.0184    0.1080
# 20717  6.0    -4.543       0.1070       0.00277            0.9110    0.1360
#
#        Valence    Tempo  Duration_ms  \
# 20713   0.6580   90.002      94667.0
# 20714   0.6570  174.869     150857.0
# 20715   0.4190  168.388     136842.0
# 20716   0.5390  155.378     108387.0
# 20717   0.0787  160.067     181500.0
#
#                                        Url_youtube  \
# 20713  https://www.youtube.com/watch?v=5SHmKFKlNqI
# 20714  https://www.youtube.com/watch?v=ocTH6KxllDQ
# 20715  https://www.youtube.com/watch?v=5wFhE-HY0hg
# 20716  https://www.youtube.com/watch?v=VMFLbFRNCn0
# 20717  https://www.youtube.com/watch?v=zau0dckCFi0
#
#                                 Title              Channel     Views   Likes  \
# 20713            JUST DANCE HARDSTYLE  SICK LEGEND - Topic   71678.0  1113.0
# 20714  SET FIRE TO THE RAIN HARDSTYLE  SICK LEGEND - Topic  164741.0  2019.0
# 20715       OUTSIDE HARDSTYLE SPED UP  SICK LEGEND - Topic   35646.0   329.0
# 20716             ONLY GIRL HARDSTYLE  SICK LEGEND - Topic    6533.0    88.0
# 20717              MISS YOU HARDSTYLE  SICK LEGEND - Topic  158697.0  2484.0
#
#        Comments                                        Description Licensed  \
# 20713       0.0  Provided to YouTube by Routenote\n\nJUST DANCE...     True
# 20714       0.0  Provided to YouTube by Routenote\n\nSET FIRE T...     True
# 20715       0.0  Provided to YouTube by Routenote\n\nOUTSIDE HA...     True
# 20716       0.0  Provided to YouTube by Routenote\n\nONLY GIRL ...     True
# 20717       0.0  Provided to YouTube by Routenote\n\nMISS YOU H...     True
#
#       official_video      Stream
# 20713           True   9227144.0
# 20714           True  10898176.0
# 20715           True   6226110.0
# 20716           True   6873961.0
# 20717           True   5695584.0

# %%
#10 filas aleatorias del *dataframe*

df.sample(10)
# Out:
#                Artist                                        Url_spotify  \
# 14818      Disclosure  https://open.spotify.com/artist/6nS5roXSAGhTGr...
# 9377          Misfits  https://open.spotify.com/artist/1cXi8ALPQCBHZb...
# 8302        DJ Nelson  https://open.spotify.com/artist/2ydZrTy8U3kOMO...
# 13346      Mike Perry  https://open.spotify.com/artist/6lB8vOoI4DRrrV...
# 19491       YNW Melly  https://open.spotify.com/artist/1cNDP5yjU5vjeR...
# 5765         Jadakiss  https://open.spotify.com/artist/5pnbUBPifNnlus...
# 9603           Yandel  https://open.spotify.com/artist/0eHQ9o50hj6ZDN...
# 2250   Sufjan Stevens  https://open.spotify.com/artist/4MXUO7sVCaFgFj...
# 11415             WWE  https://open.spotify.com/artist/0spHbv2fw49lDM...
# 33          Metallica  https://open.spotify.com/artist/2ye2Wgw4gimLv2...
#
#                                                    Track  \
# 14818                                              Latch
# 9377                   Last Caress - C.I. Recording 1978
# 8302                                           No Confío
# 13346                                          I Like It
# 19491             Mixed Personalities (feat. Kanye West)
# 5765   New York (feat. A Boogie Wit Da Hoodie & Jadak...
# 9603                         Explícale (feat. Bad Bunny)
# 2250                            Should Have Known Better
# 11415                               Voices (Randy Orton)
# 33                                    Whiskey In The Jar
#
#                                     Album Album_type  \
# 14818                     Settle (Deluxe)      album
# 9377                  The Misfits Box Set      album
# 8302                            Emociones      album
# 13346                           I Like It     single
# 19491                        We All Shine      album
# 5765                      Rebel vs. Rowdy      album
# 9603                              #Update      album
# 2250                      Carrie & Lowell      album
# 11415  WWE: WrestleMania - The Music 2013      album
# 33                           Garage, Inc.      album
#
#                                         Uri  Danceability  Energy   Key  \
# 14818  spotify:track:1DunhgeZSEgWiIYbHqXl0c         0.729   0.735   1.0
# 9377   spotify:track:5ALCHMO9Fmvn1Ly18Q3apL         0.330   0.906   0.0
# 8302   spotify:track:2UieOcTk0Kl4bzLVBW4oVj         0.927   0.551   1.0
# 13346  spotify:track:2mAZiqOgpOQ3Wcnxxizcsf         0.659   0.839  10.0
# 19491  spotify:track:6vWEAOUSxohKxhp0K1BsxL         0.661   0.440   2.0
# 5765   spotify:track:1HVVrtjLvEQx8oinUYI5Nv         0.465   0.546   5.0
# 9603   spotify:track:1LszjjoVwDDZcWUQbzeDLG         0.808   0.690   1.0
# 2250   spotify:track:3AyuigFWbuirWHvidbMz8O         0.493   0.171   7.0
# 11415  spotify:track:3xufMoKtkjMbZmVhgB2MZc         0.480   0.648   0.0
# 33     spotify:track:3ZpWy5rBZv2aLQAldnmTsP         0.511   0.972  10.0
#
#        Loudness  Speechiness  Acousticness  Instrumentalness  Liveness  \
# 14818    -5.455       0.0919      0.017800          0.000193    0.0890
# 9377     -9.607       0.0513      0.533000          0.020800    0.1500
# 8302     -7.704       0.0986      0.123000          0.002690    0.1150
# 13346    -5.862       0.0672      0.037700          0.000000    0.0687
# 19491    -9.104       0.0803      0.457000          0.000000    0.1280
# 5765     -8.749       0.2950      0.077000          0.000000    0.3140
# 9603     -4.151       0.1480      0.058300          0.000000    0.1030
# 2250    -20.696       0.0317      0.980000          0.263000    0.1260
# 11415   -10.809       0.0293      0.000387          0.000000    0.1180
# 33       -3.751       0.0413      0.000005          0.001010    0.1900
#
#        Valence    Tempo  Duration_ms  \
# 14818    0.544  121.986     255867.0
# 9377     0.418   91.186     117080.0
# 8302     0.304  119.982     213000.0
# 13346    0.726  126.064     163810.0
# 19491    0.352  149.937     230400.0
# 5765     0.186   97.886     235200.0
# 9603     0.640  125.086     223147.0
# 2250     0.296   90.928     307698.0
# 11415    0.672  165.012     204636.0
# 33       0.532  132.970     304893.0
#
#                                        Url_youtube  \
# 14818  https://www.youtube.com/watch?v=93ASUImTedo
# 9377   https://www.youtube.com/watch?v=F39UP1mjAnc
# 8302   https://www.youtube.com/watch?v=90bdiZhz-SI
# 13346  https://www.youtube.com/watch?v=Ev4Uhx9AyVI
# 19491  https://www.youtube.com/watch?v=iFv6BXjnKRU
# 5765   https://www.youtube.com/watch?v=oa96OPhV59s
# 9603   https://www.youtube.com/watch?v=U516oP9nt2o
# 2250   https://www.youtube.com/watch?v=lJJT00wqlOo
# 11415  https://www.youtube.com/watch?v=pM76LtznNrc
# 33     https://www.youtube.com/watch?v=wsrvmNtWU4E
#
#                                                    Title  \
# 14818  Disclosure - Latch feat. Sam Smith  (Official ...
# 9377                           The Misfits - Last Caress
# 8302   Jay Wheeler x El Alfa x DJ Nelson - No Confío ...
# 13346             Mike Perry feat. Hot Shade - I Like It
# 19491  YNW Melly ft. Kanye West - Mixed Personalities...
# 5765   Rowdy Rebel - New York (Official Music Video) ...
# 9603   Yandel - Explícale (Official Video) ft. Bad Bunny
# 2250   Sufjan Stevens, "Should Have Known Better" (Of...
# 11415  Randy Orton - Voices (Entrance Theme) feat. Re...
# 33     Metallica - Whiskey In The Jar (Official Music...
#
#                        Channel        Views      Likes  Comments  \
# 14818               Disclosure  422714286.0  2389006.0   63448.0
# 9377                Dean Champ    8501101.0    55099.0    2685.0
# 8302               Jay Wheeler   19414976.0   235674.0    5061.0
# 13346             Chill Master       6260.0       98.0       2.0
# 19491         Lyrical Lemonade  162215234.0  1791979.0   89803.0
# 5765            RowdyRebelVEVO    5398591.0    77888.0    3330.0
# 9603                YandelVEVO  236116064.0  1321185.0   23936.0
# 2250   Asthmatic Kitty Records   18188095.0   161891.0    4407.0
# 11415                 WWEMusic   32869952.0   324673.0   13312.0
# 33        Warner Records Vault  107553434.0   429797.0   12074.0
#
#                                              Description Licensed  \
# 14818  ENERGY the new album, OUT NOW\nhttps://disclos...    False
# 9377   Last Caress, from The Misfits EP Beware (1980)...    False
# 8302   Video Oficial de Jay Wheeler y El Alfa - No Co...    False
# 13346  Artist - Mike Perry, Hot Shade\nName- I Like I...    False
# 19491  Check out the official music video for "Mixed ...    False
# 5765   Rowdy Rebel feat. A Boogie Wit Da Hoodie & Jad...     True
# 9603   Yandel ft. Bad Bunny - "Explícale" (Official M...     True
# 2250   From the album CARRIE & LOWELL\nBuy it: http:/...     True
# 11415  Randy Orton - Voices (Entrance Theme) feat. Re...     True
# 33     “Whiskey In The Jar” by Metallica from the alb...    False
#
#       official_video       Stream
# 14818           True  820752768.0
# 9377           False   66902959.0
# 8302            True   13643125.0
# 13346          False    5555742.0
# 19491          False  368334796.0
# 5765            True    4421606.0
# 9603            True  266695813.0
# 2250            True  111668452.0
# 11415           True   33895442.0
# 33             False  327681785.0

# %%
#¿Cuántas filas y columnas tenemos en el *dataframe* 

df.shape
# Out:
# (20718, 27)

# %%
#¿Cuáles son los tipos de los datos de cada columna del *dataframe* 

df.dtypes
# Out:
# Artist               object
# Url_spotify          object
# Track                object
# Album                object
# Album_type           object
# Uri                  object
# Danceability        float64
# Energy              float64
# Key                 float64
# Loudness            float64
# Speechiness         float64
# Acousticness        float64
# Instrumentalness    float64
# Liveness            float64
# Valence             float64
# Tempo               float64
# Duration_ms         float64
# Url_youtube          object
# Title                object
# Channel              object
# Views               float64
# Likes               float64
# Comments            float64
# Description          object
# Licensed             object
# official_video       object
# Stream              float64
# dtype: object

# %%
#¿Cuántos valores nulos tenemos por columna?

df.isnull().sum()
# Out:
# Artist                0
# Url_spotify           0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Url_youtube         470
# Title               470
# Channel             470
# Views               470
# Likes               541
# Comments            569
# Description         876
# Licensed            470
# official_video      470
# Stream              576
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# artist              0.000000
# url_spotify         0.000000
# track               0.000000
# album               0.000000
# album_type          0.000000
# uri                 0.000000
# danceability        0.009653
# energy              0.009653
# key                 0.000000
# loudness            0.009653
# speechiness         0.009653
# acousticness        0.009653
# instrumentalness    0.009653
# liveness            0.009653
# valence             0.009653
# tempo               0.009653
# duration_ms         0.009653
# url_youtube         2.268559
# title               2.268559
# channel             2.268559
# views               2.268559
# likes               2.611256
# comments            2.746404
# description         4.228207
# licensed            2.268559
# official_video      2.268559
# stream              2.780191
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#¿Tenemos filas duplicadas en el *dataframe* ?
duplicates = df[df.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [Artist, Url_spotify, Track, Album, Album_type, Uri, Danceability, Energy, Key, Loudness, Speechiness, Acousticness, Instrumentalness, Liveness, Valence, Tempo, Duration_ms, Url_youtube, Title, Channel, Views, Likes, Comments, Description, Licensed, official_video, Stream]
# Index: []

# %%
#Muestra los principales estadísticos para las columnas numéricas del *dataframe* 
df.describe().T

#aqui se puede ver que hay negativos que no son lógicos, por ejemplo.
# Out:
#                     count          mean           std           min  \
# Danceability      20716.0  6.197775e-01  1.652724e-01      0.000000
# Energy            20716.0  6.352503e-01  2.141468e-01      0.000020
# Key               20716.0  5.300348e+00  3.576449e+00      0.000000
# Loudness          20716.0 -7.671680e+00  4.632749e+00    -46.251000
# Speechiness       20716.0  9.645601e-02  1.119600e-01      0.000000
# Acousticness      20716.0  2.915353e-01  2.862988e-01      0.000001
# Instrumentalness  20716.0  5.596156e-02  1.932620e-01      0.000000
# Liveness          20716.0  1.935210e-01  1.685309e-01      0.014500
# Valence           20716.0  5.298533e-01  2.454408e-01      0.000000
# Tempo             20716.0  1.206383e+02  2.957902e+01      0.000000
# Duration_ms       20716.0  2.247176e+05  1.247905e+05  30985.000000
# Views             20248.0  9.393782e+07  2.746443e+08      0.000000
# Likes             20177.0  6.633411e+05  1.789324e+06      0.000000
# Comments          20149.0  2.751899e+04  1.932347e+05      0.000000
# Stream            20142.0  1.359422e+08  2.441321e+08   6574.000000
#
#                            25%           50%           75%           max
# Danceability      5.180000e-01  6.370000e-01  7.402500e-01  9.750000e-01
# Energy            5.070000e-01  6.660000e-01  7.980000e-01  1.000000e+00
# Key               2.000000e+00  5.000000e+00  8.000000e+00  1.100000e+01
# Loudness         -8.858000e+00 -6.536000e+00 -4.931000e+00  9.200000e-01
# Speechiness       3.570000e-02  5.050000e-02  1.030000e-01  9.640000e-01
# Acousticness      4.520000e-02  1.930000e-01  4.772500e-01  9.960000e-01
# Instrumentalness  0.000000e+00  2.405000e-06  4.630000e-04  1.000000e+00
# Liveness          9.410000e-02  1.250000e-01  2.370000e-01  1.000000e+00
# Valence           3.390000e-01  5.370000e-01  7.262500e-01  9.930000e-01
# Tempo             9.700200e+01  1.199650e+02  1.399350e+02  2.433720e+02
# Duration_ms       1.800095e+05  2.132845e+05  2.524430e+05  4.676058e+06
# Views             1.826002e+06  1.450110e+07  7.039975e+07  8.079649e+09
# Likes             2.158100e+04  1.244810e+05  5.221480e+05  5.078865e+07
# Comments          5.090000e+02  3.277000e+03  1.436000e+04  1.608314e+07
# Stream            1.767486e+07  4.968298e+07  1.383581e+08  3.386520e+09

# %%
#Muestra los principales estadísticos para las columnas categóricas del *dataframe* 

df.describe(include = "O").T
# Out:
#                 count unique  \
# Artist          20718   2079
# Url_spotify     20718   2079
# Track           20718  17841
# Album           20718  11937
# Album_type      20718      3
# Uri             20718  18862
# Url_youtube     20248  18154
# Title           20248  18146
# Channel         20248   6714
# Description     19842  17395
# Licensed        20248      2
# official_video  20248      2
#
#                                                               top   freq
# Artist                                                SICK LEGEND     10
# Url_spotify     https://open.spotify.com/artist/3EYY5FwDkHEYLw...     10
# Track                   El Ultimo Adiós - Varios Artistas Version     24
# Album                                               Greatest Hits     30
# Album_type                                                  album  14926
# Uri                          spotify:track:0tzixmHNQfE6S6SirSToxW     24
# Url_youtube           https://www.youtube.com/watch?v=GqOvxbFLwjY     18
# Title           Color Esperanza 2020 - Various Artists (Offici...     18
# Channel                                                  T-Series    238
# Description                                                          114
# Licensed                                                     True  14140
# official_video                                               True  15723

# %% [markdown]
# 2. Preparación de los datos:
#
#     - Los nombres de las columnas empiezan con mayúsculas, pon todos los nombres de las columnas en minúsculas.
#
#     - Haciendo el análisis exploratorio te deberías haber dado cuenta de que algunas de las variables (`danceability`, `energy`, `key`, `loudness`, `speechiness`, `acousticness`, `instrumentalness`) no son del tipo que deberían. Esto es debido a que los decimales están establecidos como comas y no con puntos. Crea una función que nos permita cambiar esas comas por puntos para que los datos tengan el tipo correcto.
#
#         - Después de haber hecho los cambios, chequea los tipos de datos. ¿Son ya del tipo correcto? En caso de que no, crea otra función o modifica la anterior para que sean de tipo *float*.
#
#     - Hay algunas canciones cuyo título está en mayúsculas. Crea una función para que todos los títulos estén en minúscula. Haz lo mismo para las columnas de "title" y "album".
#
#     - Algunos de los artistas tienen símbolos raros, en concreto el símbolo `$`. Crea una función que los reemplaza por "s".

# %%
#Los nombres de las columnas empiezan con mayúsculas, pon todos los nombres de las columnas en minúsculas. 

df.columns = df.columns.str.lower()
df.head(2)

#ANOTHER OPTION:
#nuevas_cols = {col: col.lower() for col in df.columns}
#df.rename(columns=nuevas_cols, inplace=True)
# Out:
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#              track          album album_type  \
# 0   Feel Good Inc.     Demon Days      album
# 1  Rhinestone Eyes  Plastic Beach      album
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0    -6.679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703  8.0    -5.815
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1770       0.00836          0.002330    0.6130    0.772  138.559
# 1       0.0302       0.08690          0.000687    0.0463    0.852   92.761
#
#    duration_ms                                  url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1     200173.0  https://www.youtube.com/watch?v=yYDmaexVHic
#
#                                                title   channel        views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
#        likes  comments                                        description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
#   licensed official_video        stream
# 0     True           True  1.040235e+09
# 1     True           True  3.100837e+08

# %%
df.columns
# Out:
# Index(['artist', 'url_spotify', 'track', 'album', 'album_type', 'uri',
#        'danceability', 'energy', 'key', 'loudness', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'url_youtube', 'title', 'channel', 'views', 'likes',
#        'comments', 'description', 'licensed', 'official_video', 'stream'],
#       dtype='object')

# %% [markdown]
# We didn't end up using this fuction because the data had periods instead of commas and was already tipo float.
#
# def cambiar_comas(x):
#     try:
#         return float(x.replace(",", "."))
#     except:
#         return np.nan
# lista_columnas = ['danceability', 'energy', 'key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness']
# for i in lista_columnas:
#     df[i] = df[i].apply(cambiar_comas)

# %%
df['key'] = df['key'].fillna("999")

#must use 999 instead of 'Unknown" so that after it can be converted to INT

# %%
df['key'].unique()
# Out:
# array([6.0, 8.0, 1.0, 2.0, 10.0, 11.0, 4.0, 9.0, 0.0, 7.0, 5.0, 3.0,
#        '999'], dtype=object)

# %%
df['key'] = df['key'].astype(int)

# %%
#Hay algunas canciones cuyo título está en mayúsculas. Crea una función para que todos los títulos estén en minúscula. Haz lo mismo para las columnas de "title" y "album".

def cadena_lower (cadena):
    return cadena.replace.str.lower()

columnas_cambiar_lower = ['track', 'title', 'album']

for col in columnas_cambiar_lower:
    df[col] = df[col].str.lower()


df.sample(5)
# Out:
#               artist                                        url_spotify  \
# 20425        ENHYPEN  https://open.spotify.com/artist/5t5FqBwTcgKTaW...
# 14675  Pablo Alborán  https://open.spotify.com/artist/5M9Bb4adKAgrOF...
# 16141  Glass Animals  https://open.spotify.com/artist/4yvcSjfu4PC0CY...
# 4197           Skank  https://open.spotify.com/artist/4C4kpaAdp6aKSk...
# 19897       24kGoldn  https://open.spotify.com/artist/6fWVd57NKTalqv...
#
#                                                    track  \
# 20425                                        drunk-dazed
# 14675               rayando el sol (feat. pablo alborán)
# 16141                                              gooey
# 4197                                     garota nacional
# 19897  mood (remix) feat. justin bieber, j balvin & i...
#
#                                                    album album_type  \
# 20425                                  border : carnival     single
# 14675               rayando el sol (feat. pablo alborán)     single
# 16141                                               zaba      album
# 4197                                      o samba poconé      album
# 19897  mood (remix) feat. justin bieber, j balvin & i...     single
#
#                                         uri  danceability  energy  key  \
# 20425  spotify:track:1wcr8DjnN59Awev8nnKpQ4         0.599   0.869    5
# 14675  spotify:track:3uKdu7AtigAJ8GgTu0yJTe         0.627   0.456    7
# 16141  spotify:track:1gk3FhAV07q9Jg77UxnVjX         0.487   0.369   11
# 4197   spotify:track:7DoBn08dqKS9MmtZiZChVD         0.860   0.769    0
# 19897  spotify:track:6FuGJB290AQMAHTfjOYVaK         0.721   0.745    7
#
#        loudness  speechiness  acousticness  instrumentalness  liveness  \
# 20425    -5.174       0.0618      0.000707          0.000000    0.0911
# 14675    -7.143       0.0281      0.314000          0.000000    0.0901
# 16141   -13.424       0.0406      0.736000          0.000037    0.0925
# 4197     -5.087       0.0342      0.003960          0.000114    0.1130
# 19897    -3.508       0.0366      0.151000          0.000001    0.3720
#
#        valence    tempo  duration_ms  \
# 20425    0.453  132.889     193260.0
# 14675    0.193  122.025     258937.0
# 16141    0.106  183.114     289307.0
# 4197     0.808  130.108     317400.0
# 19897    0.699   90.988     192745.0
#
#                                        url_youtube  \
# 20425  https://www.youtube.com/watch?v=Fc7-Oe0tj5k
# 14675  https://www.youtube.com/watch?v=bE3ABNHDnAc
# 16141  https://www.youtube.com/watch?v=IIA1XQnAv5s
# 4197   https://www.youtube.com/watch?v=DjPtwYunRq4
# 19897  https://www.youtube.com/watch?v=f1J4dRTMy9A
#
#                                                    title           channel  \
# 20425           enhypen (엔하이픈) 'drunk-dazed' official mv       HYBE LABELS
# 14675  maná - rayando el sol (feat. pablo alborán) [v...       OficialMana
# 16141             glass animals - gooey (official video)  GlassAnimalsVEVO
# 4197             skank - garota nacional (clipe oficial)         SkankVEVO
# 19897  24kgoldn - mood remix (lyrics) ft. justin bieb...           7clouds
#
#              views      likes  comments  \
# 20425   99088923.0  3725153.0  441523.0
# 14675  108875949.0   627583.0   17456.0
# 16141   20513451.0   153280.0    4167.0
# 4197     5388246.0    71302.0    3990.0
# 19897   34408366.0   230490.0    3535.0
#
#                                              description licensed  \
# 20425  ENHYPEN (엔하이픈) 'Drunk-Dazed' Official MV\n\nCr...     True
# 14675                                                NaN     True
# 16141  ‘dreamland IRL’ is out. it’s about revisiting ...     True
# 4197   Clipe Oficial de "Garota Nacional" do Skank, p...     True
# 19897  🎵 Follow 7clouds on Spotify : http://bit.ly/7C...     True
#
#       official_video       stream
# 20425           True  169511209.0
# 14675           True  139727244.0
# 16141           True  295935353.0
# 4197            True   35692885.0
# 19897           True  223499126.0

# %%
#Algunos de los artistas tienen símbolos raros, en concreto el símbolo `$`. Crea una función que los reemplaza por "s". 

df['artist'] = df['artist'].str.replace('s', '$')


df[df['artist'].str.contains('$', na=False)]
# Out:
#             artist                                        url_spotify  \
# 0         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...            ...                                                ...
# 20713  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                                track  \
# 0                                     feel good inc.
# 1                                    rhinestone eyes
# 2      new gold (feat. tame impala and bootie brown)
# 3                                 on melancholy hill
# 4                                     clint eastwood
# ...                                              ...
# 20713                           just dance hardstyle
# 20714                 set fire to the rain hardstyle
# 20715                      outside hardstyle sped up
# 20716                            only girl hardstyle
# 20717                             miss you hardstyle
#
#                                                album album_type  \
# 0                                         demon days      album
# 1                                      plastic beach      album
# 2      new gold (feat. tame impala and bootie brown)     single
# 3                                      plastic beach      album
# 4                                           gorillaz      album
# ...                                              ...        ...
# 20713                           just dance hardstyle     single
# 20714                 set fire to the rain hardstyle     single
# 20715                      outside hardstyle sped up     single
# 20716                            only girl hardstyle     single
# 20717                             miss you hardstyle     single
#
#                                         uri  danceability  energy  key  \
# 0      spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705    6
# 1      spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703    8
# 2      spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923    1
# 3      spotify:track:0q6LuUqGLUiCPP1cbdwFs3         0.689   0.739    2
# 4      spotify:track:7yMiX7n9SBvadzox8T5jzT         0.663   0.694   10
# ...                                     ...           ...     ...  ...
# 20713  spotify:track:0RtcKQGyI4hr8FgFH1TuYG         0.582   0.926    5
# 20714  spotify:track:3rHvPA8lUnPBkaLyPOc0VV         0.531   0.936    4
# 20715  spotify:track:4jk00YxPtPbhvHJE9N4ddv         0.443   0.830    4
# 20716  spotify:track:5EyErbpsugWliX006eTDex         0.417   0.767    9
# 20717  spotify:track:6lOn0jz1QpjcWeXo1oMm0k         0.498   0.938    6
#
#        loudness  speechiness  acousticness  instrumentalness  liveness  \
# 0        -6.679       0.1770      0.008360          0.002330    0.6130
# 1        -5.815       0.0302      0.086900          0.000687    0.0463
# 2        -3.930       0.0522      0.042500          0.046900    0.1160
# 3        -5.810       0.0260      0.000015          0.509000    0.0640
# 4        -8.627       0.1710      0.025300          0.000000    0.0698
# ...         ...          ...           ...               ...       ...
# 20713    -6.344       0.0328      0.448000          0.000000    0.0839
# 20714    -1.786       0.1370      0.028000          0.000000    0.0923
# 20715    -4.679       0.0647      0.024300          0.000000    0.1540
# 20716    -4.004       0.4190      0.356000          0.018400    0.1080
# 20717    -4.543       0.1070      0.002770          0.911000    0.1360
#
#        valence    tempo  duration_ms  \
# 0       0.7720  138.559     222640.0
# 1       0.8520   92.761     200173.0
# 2       0.5510  108.014     215150.0
# 3       0.5780  120.423     233867.0
# 4       0.5250  167.953     340920.0
# ...        ...      ...          ...
# 20713   0.6580   90.002      94667.0
# 20714   0.6570  174.869     150857.0
# 20715   0.4190  168.388     136842.0
# 20716   0.5390  155.378     108387.0
# 20717   0.0787  160.067     181500.0
#
#                                        url_youtube  \
# 0      https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1      https://www.youtube.com/watch?v=yYDmaexVHic
# 2      https://www.youtube.com/watch?v=qJa-VFwPpYA
# 3      https://www.youtube.com/watch?v=04mfKJWDSzI
# 4      https://www.youtube.com/watch?v=1V_xRb0x9aw
# ...                                            ...
# 20713  https://www.youtube.com/watch?v=5SHmKFKlNqI
# 20714  https://www.youtube.com/watch?v=ocTH6KxllDQ
# 20715  https://www.youtube.com/watch?v=5wFhE-HY0hg
# 20716  https://www.youtube.com/watch?v=VMFLbFRNCn0
# 20717  https://www.youtube.com/watch?v=zau0dckCFi0
#
#                                                    title              channel  \
# 0             gorillaz - feel good inc. (official video)             Gorillaz
# 1      gorillaz - rhinestone eyes [storyboard film] (...             Gorillaz
# 2      gorillaz - new gold ft. tame impala & bootie b...             Gorillaz
# 3         gorillaz - on melancholy hill (official video)             Gorillaz
# 4             gorillaz - clint eastwood (official video)             Gorillaz
# ...                                                  ...                  ...
# 20713                               just dance hardstyle  SICK LEGEND - Topic
# 20714                     set fire to the rain hardstyle  SICK LEGEND - Topic
# 20715                          outside hardstyle sped up  SICK LEGEND - Topic
# 20716                                only girl hardstyle  SICK LEGEND - Topic
# 20717                                 miss you hardstyle  SICK LEGEND - Topic
#
#              views      likes  comments  \
# 0      693555221.0  6220896.0  169907.0
# 1       72011645.0  1079128.0   31003.0
# 2        8435055.0   282142.0    7399.0
# 3      211754952.0  1788577.0   55229.0
# 4      618480958.0  6197318.0  155930.0
# ...            ...        ...       ...
# 20713      71678.0     1113.0       0.0
# 20714     164741.0     2019.0       0.0
# 20715      35646.0      329.0       0.0
# 20716       6533.0       88.0       0.0
# 20717     158697.0     2484.0       0.0
#
#                                              description licensed  \
# 0      Official HD Video for Gorillaz' fantastic trac...     True
# 1      The official video for Gorillaz - Rhinestone E...     True
# 2      Gorillaz - New Gold ft. Tame Impala & Bootie B...     True
# 3      Follow Gorillaz online:\nhttp://gorillaz.com \...     True
# 4      The official music video for Gorillaz - Clint ...     True
# ...                                                  ...      ...
# 20713  Provided to YouTube by Routenote\n\nJUST DANCE...     True
# 20714  Provided to YouTube by Routenote\n\nSET FIRE T...     True
# 20715  Provided to YouTube by Routenote\n\nOUTSIDE HA...     True
# 20716  Provided to YouTube by Routenote\n\nONLY GIRL ...     True
# 20717  Provided to YouTube by Routenote\n\nMISS YOU H...     True
#
#       official_video        stream
# 0               True  1.040235e+09
# 1               True  3.100837e+08
# 2               True  6.306347e+07
# 3               True  4.346636e+08
# 4               True  6.172597e+08
# ...              ...           ...
# 20713           True  9.227144e+06
# 20714           True  1.089818e+07
# 20715           True  6.226110e+06
# 20716           True  6.873961e+06
# 20717           True  5.695584e+06
#
# [20718 rows x 27 columns]

# %% [markdown]
# 3. 4. Filtrado de datos:
#
#     - ¿Cuáles son los valores únicos de la columna "album_type"? Crea tres *dataframes* diferentes, uno para cada tipo de "album_type". ¿Cuántas canciones tenemos en cada tipo?
#
#     - Usando el *dataframe* de los albumes que hemos creado en el ejercicio anterior. ¿Cuál es la media y la desviación estándar de "danceability", "acousticness" y "speechiness" de cada artista?. Muesrtra los resultados en tres dataframes diferentes, uno para cada métrica ("danceability", "acousticness" y "speechiness"). Ordena los resultados de mayor a menor en base a la media.
#
#
#     - Se quiere estudiar si existe una relación entre la cantidad de visitas que reciben los videos de música de un artista en una plataforma de streaming y la cantidad de likes que estos videos obtienen. Por lo tanto, queremos contestar a la siguiente pregunta: ¿Son aquellos artistas que tienen más visitas los que más likes tienen? Para solucionar este ejercicio deberéis:
#
#         - Agrupa por artista y calcular la media de visitas y de likes.
#
#         - Quedate con los 10 artistas que más visitas han tenido.
#
#         - Quedate con los 10 artistas que más likes han tenido.
#
#         - **BONUS** Haced lo mismo para los datos de tipo "single".

# %%
df['album_type'].unique()
# Out:
# array(['album', 'single', 'compilation'], dtype=object)

# %%
df_album = df[df["album_type"] == "album"]

df_album.head(2)
# Out:
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#              track          album album_type  \
# 0   feel good inc.     demon days      album
# 1  rhinestone eyes  plastic beach      album
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705    6    -6.679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703    8    -5.815
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1770       0.00836          0.002330    0.6130    0.772  138.559
# 1       0.0302       0.08690          0.000687    0.0463    0.852   92.761
#
#    duration_ms                                  url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1     200173.0  https://www.youtube.com/watch?v=yYDmaexVHic
#
#                                                title   channel        views  \
# 0         gorillaz - feel good inc. (official video)  Gorillaz  693555221.0
# 1  gorillaz - rhinestone eyes [storyboard film] (...  Gorillaz   72011645.0
#
#        likes  comments                                        description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
#   licensed official_video        stream
# 0     True           True  1.040235e+09
# 1     True           True  3.100837e+08

# %%
df_album.shape
# Out:
# (14926, 27)

# %%
df_single = df[df["album_type"] == "single"]

df_single.head(2)
# Out:
#      artist                                        url_spotify  \
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 6  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                                track  \
# 2      new gold (feat. tame impala and bootie brown)
# 6  new gold (feat. tame impala and bootie brown) ...
#
#                                                album album_type  \
# 2      new gold (feat. tame impala and bootie brown)     single
# 6  new gold (feat. tame impala and bootie brown) ...     single
#
#                                     uri  danceability  energy  key  loudness  \
# 2  spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923    1    -3.930
# 6  spotify:track:2c3KCGq6UojB2c8UAFrRON         0.716   0.897    4    -7.185
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 2       0.0522        0.0425            0.0469     0.116    0.551  108.014
# 6       0.0629        0.0120            0.2620     0.325    0.358  127.030
#
#    duration_ms                                  url_youtube  \
# 2     215150.0  https://www.youtube.com/watch?v=qJa-VFwPpYA
# 6     274142.0  https://www.youtube.com/watch?v=BONNm0F7Tto
#
#                                                title    channel      views  \
# 2  gorillaz - new gold ft. tame impala & bootie b...   Gorillaz  8435055.0
# 6  gorillaz - new gold ft. tame impala, bootie br...  Dom Dolla   451996.0
#
#       likes  comments                                        description  \
# 2  282142.0    7399.0  Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 6   11686.0     241.0  Gorillaz 'New Gold' ft. Tame Impala, Bootie Br...
#
#   licensed official_video      stream
# 2     True           True  63063467.0
# 6    False           True  10666154.0

# %%
df_single.shape
# Out:
# (5004, 27)

# %%
df_compilation = df[df["album_type"] == "compilation"]

df_compilation.head(2)
# Out:
#         artist                                        url_spotify  \
# 154    Shakira  https://open.spotify.com/artist/0EmeFodog0BfCg...
# 206  Sean Paul  https://open.spotify.com/artist/3Isy6kedDrgPYo...
#
#                                                  track  \
# 154  waka waka (this time for africa) [the official...
# 206  (when you gonna) give it up to me (feat. keysh...
#
#                                                  album   album_type  \
# 154  listen up! the official 2010 fifa world cup album  compilation
# 206                                          only hits  compilation
#
#                                       uri  danceability  energy  key  \
# 154  spotify:track:6bNB5gxFX6Q87DbQWb8OWZ         0.758   0.871    2
# 206  spotify:track:6k8uthjEbttfWXcGaNTQGD         0.711   0.761    8
#
#      loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 154    -6.408        0.147        0.0062               0.0    0.0663    0.753
# 206    -3.040        0.225        0.0670               0.0    0.0410    0.718
#
#        tempo  duration_ms                                  url_youtube  \
# 154  126.994     202627.0  https://www.youtube.com/watch?v=pRpeEdMmmQ0
# 206   95.824     243880.0  https://www.youtube.com/watch?v=bMoNV9oWs2E
#
#                                                  title           channel  \
# 154  shakira - waka waka (this time for africa) (th...       shakiraVEVO
# 206  sean paul - give it up to me (feat. keyshia co...  Atlantic Records
#
#             views       likes   comments  \
# 154  3.463816e+09  20327883.0  1283529.0
# 206  3.068871e+08   1317175.0    17399.0
#
#                                            description licensed  \
# 154  Watch the official music video for "Waka Waka ...     True
# 206  The official video of "Give It Up To Me (feat....     True
#
#     official_video       stream
# 154           True  629918488.0
# 206           True   51339097.0

# %%
df_compilation.shape
# Out:
# (788, 27)

# %% [markdown]
#  Usando el *dataframe* de los albumes que hemos creado en el ejercicio anterior. ¿Cuál es la media y la desviación estándar de "danceability", "acousticness" y "speechiness" de cada artista?. Muesrtra los resultados en tres dataframes diferentes, uno para cada métrica ("danceability", "acousticness" y "speechiness"). Ordena los resultados de mayor a menor en base a la media.

# %%
columnas = ["danceability", "acousticness", "speechiness"]

# %%
stats_df_album = df_album.groupby('artist')[columnas].agg(["mean", "std"])

stats_df_album.head(3)
# Out:
#           danceability           acousticness           speechiness
#                   mean       std         mean       std        mean       std
# artist
# (G)I-DLE       0.79650  0.058690     0.048140  0.054108     0.12880  0.049780
# *NSYNC         0.62240  0.108125     0.154031  0.180663     0.05752  0.036145
# 070 Shake      0.65375  0.086001     0.027217  0.027811     0.06790  0.048658

# %%
#I need a separate dataframe for each metric. And sort the order. 

stats_danceability = df_album.groupby('artist')['danceability'].agg(["mean", "std"])

stats_danceability_sorted = stats_danceability.sort_values(by="mean", ascending=False)

stats_danceability_sorted.head(3)
# Out:
#             mean       std
# artist
# Latto   0.922333  0.014503
# Murda   0.911500  0.030406
# Jon Z   0.886000  0.015556

# %%
stats_acousticness = df_album.groupby('artist')['acousticness'].agg(["mean", "std"])

stats_acousticness_sorted = stats_acousticness.sort_values(by="mean", ascending=False)

stats_acousticness_sorted.head(3)
# Out:
#                      mean       std
# artist
# Claude Debussy   0.993714  0.001380
# Robert Schumann  0.993444  0.004902
# Franz Schubert   0.989500  0.005237

# %%
stats_speechiness = df_album.groupby('artist')['speechiness'].agg(["mean", "std"])

stats_speechiness_sorted = stats_speechiness.sort_values(by="mean", ascending=False)

stats_speechiness_sorted.head(3)
# Out:
#                           mean       std
# artist
# Sir Arthur Conan Doyle  0.9523  0.008845
# Bibi Blocksberg         0.9453  0.011879
# Sherlock Holmes         0.9393  0.015833

# %% [markdown]
#     - Se quiere estudiar si existe una relación entre la cantidad de visitas que reciben los videos de música de un artista en una plataforma de streaming y la cantidad de likes que estos videos obtienen. Por lo tanto, queremos contestar a la siguiente pregunta: ¿Son aquellos artistas que tienen más visitas los que más likes tienen? Para solucionar este ejercicio deberéis:
#
#         - Agrupa por artista y calcular la media de visitas y de likes.
#
#         - Quedate con los 10 artistas que más visitas han tenido.
#
#         - Quedate con los 10 artistas que más likes han tenido.

# %%
columnas = ['views', 'likes'] 

df_visitas = df.groupby('artist')[columnas].mean()

df_visitas_sorted = df_visitas.sort_values(by='views', ascending=False)

df_visitas_sorted.head(10)
# Out:
#                                 views      likes
# artist
# Ed Sheeran               1.546021e+09  8354331.9
# CoComelon                1.460167e+09  4171391.3
# Katy Perry               1.312063e+09  6306709.0
# Charlie Puth             1.216759e+09  8633692.5
# Luis Fonsi               1.162811e+09  6690848.9
# Justin Bieber            1.099106e+09  7858434.8
# Daddy Yankee             1.087193e+09  6551817.1
# Bruno Mars               1.024092e+09  5961614.6
# Macklemore & Ryan Lewis  1.012206e+09  6604141.0
# Coldplay                 9.997278e+08  6315789.5

# %%
columnas = ['views', 'likes'] 

df_likes = df.groupby('artist')[columnas].mean()

df_likes_sorted = df_likes.sort_values(by='likes', ascending=False)

df_likes_sorted.head(10)
# Out:
#                         views       likes
# artist
# BTS              5.607867e+08  13940380.8
# BLACKPINK        9.392962e+08  13230250.5
# Charlie Puth     1.216759e+09   8633692.5
# Ed Sheeran       1.546021e+09   8354331.9
# Ju$tin Bieber    1.099106e+09   7858434.8
# Billie Eili$h    4.821569e+08   7333853.7
# Imagine Dragon$  9.093785e+08   7227447.7
# Alan Walker      7.256847e+08   6797770.2
# DJ Snake         9.180268e+08   6777583.1
# Lui$ Fon$i       1.162811e+09   6690848.9

# %% [markdown]
#       - **BONUS** Haced lo mismo para los datos de tipo "single".
#
#     - Ahora queremos analizar la colaboración entre artistas en la industria musical, se tienen datos de las colaboraciones realizadas en los últimos años. Se desea conocer cuáles son los artistas que han colaborado en mayor cantidad de canciones y generar un *ranking* con los diez primeros. ¿Qué artistas con los que más colaboraciones tienen? Para esto tendréis que:
#
#         - Filtra los datos para quedarte solo con aquellos datos donde en la columna "track" tengamos "feat".
#
#         - Cuenta cuantas canciones tiene cada artista utilizando el *dataframe* generado en el paso anterior.
#
#
#         - Debes contestar a las siguientes preguntas:
#
#             - ¿Cuáles son los diez artistas que más han colaborado  según los datos que tenemos?
#
#             - ¿Cuál es el número de canciones en los que ha colaborado el artista que ocupa el primer lugar en el *ranking*?
#
#             - ¿Cuál es el artista que ocupa el décimo lugar en el *ranking* y en cuántas canciones ha colaborado?

# %%
# Filtra los datos para quedarte solo con aquellos datos donde en la columna "track" tengamos "feat".

df_filtrado_feat = df[df["track"].str.contains('feat', regex = False, na = False)]
df_filtrado_feat.head()
# Out:
#       artist                                        url_spotify  \
# 2   Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 6   Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 7   Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 8   Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 27   50 Cent  https://open.spotify.com/artist/3q7HBObVc0L8jN...
#
#                                                 track  \
# 2       new gold (feat. tame impala and bootie brown)
# 6   new gold (feat. tame impala and bootie brown) ...
# 7                  she's my collar (feat. kali uchis)
# 8                   cracker island (feat. thundercat)
# 27                 is this love ('09) (feat. 50 cent)
#
#                                                 album album_type  \
# 2       new gold (feat. tame impala and bootie brown)     single
# 6   new gold (feat. tame impala and bootie brown) ...     single
# 7                                     humanz (deluxe)      album
# 8                   cracker island (feat. thundercat)     single
# 27                                     curtain call 2      album
#
#                                      uri  danceability  energy  key  loudness  \
# 2   spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923    1    -3.930
# 6   spotify:track:2c3KCGq6UojB2c8UAFrRON         0.716   0.897    4    -7.185
# 7   spotify:track:3lIxtCaROdRDuTnNBDm3n2         0.726   0.815   11    -5.886
# 8   spotify:track:2W3ZpQg9i6lE6kmHbcdu9N         0.741   0.913    2    -3.340
# 27  spotify:track:7rK0iM6jwuo1oizdx8suQA         0.853   0.776    8    -4.221
#
#     speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 2        0.0522       0.04250            0.0469     0.116    0.551  108.014
# 6        0.0629       0.01200            0.2620     0.325    0.358  127.030
# 7        0.0313       0.00799            0.0810     0.112    0.462  140.158
# 8        0.0465       0.00343            0.1030     0.325    0.643  120.012
# 27       0.2610       0.07140            0.0000     0.181    0.659   94.028
#
#     duration_ms                                  url_youtube  \
# 2      215150.0  https://www.youtube.com/watch?v=qJa-VFwPpYA
# 6      274142.0  https://www.youtube.com/watch?v=BONNm0F7Tto
# 7      209560.0  https://www.youtube.com/watch?v=f8NwLXYIHS4
# 8      213750.0  https://www.youtube.com/watch?v=S03T47hapAc
# 27     212013.0  https://www.youtube.com/watch?v=Zl64MRAqQxk
#
#                                                 title     channel       views  \
# 2   gorillaz - new gold ft. tame impala & bootie b...    Gorillaz   8435055.0
# 6   gorillaz - new gold ft. tame impala, bootie br...   Dom Dolla    451996.0
# 7                     gorillaz - she's my collar [hq]  SalvaMuñox   1010982.0
# 8   gorillaz - cracker island ft. thundercat (offi...    Gorillaz  24459820.0
# 27  eminem, 50 cent - is this love ('09) [visualizer]  EminemVEVO   5289821.0
#
#        likes  comments                                        description  \
# 2   282142.0    7399.0  Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 6    11686.0     241.0  Gorillaz 'New Gold' ft. Tame Impala, Bootie Br...
# 7    17675.0     260.0  𝐁̲𝐎̲𝐍̲𝐔̲𝐒̲:̲ Hu̳ma̳n̳z [̲̠̲𝐃̲̠̲𝐄̲̠̲𝐅̲̠̲𝐈̲̠̲𝐍̲̠...
# 8   739527.0   20296.0  Listen to Cracker Island: https://gorillaz.lnk...
# 27  245935.0    9008.0  Listen to "Curtain Call 2": \nhttps://Eminem.l...
#
#    licensed official_video       stream
# 2      True           True   63063467.0
# 6     False           True   10666154.0
# 7     False          False  159605929.0
# 8      True           True   42671901.0
# 27     True           True   28529840.0

# %%
df_filtrado_feat['track'].unique()
# Out:
# array(['new gold (feat. tame impala and bootie brown)',
#        'new gold (feat. tame impala and bootie brown) - dom dolla remix',
#        "she's my collar (feat. kali uchis)", ...,
#        'left and right (feat. jung kook of bts) - sam feldt remix',
#        'left and right (feat. jung kook of bts) - galantis remix',
#        'left and right (feat. jung kook of bts) - instrumental'],
#       shape=(1505,), dtype=object)

# %%
#Cuenta cuantas canciones tiene cada artista utilizando el *dataframe* generado en el paso anterior.

recuento = df_filtrado_feat.groupby('artist')['track'].count()

recuento
# Out:
# artist
# 070 Shake            1
# 112                  4
# 1nonly               1
# 2 Chainz             1
# 21 Savage            2
#                     ..
# sNOT                 4
# sped up nightcore    1
# thasup               8
# Ñejo                 1
# Ñengo Flow           1
# Name: track, Length: 702, dtype: int64

# %%
#¿Cuáles son los diez artistas que más han colaborado  según los datos que tenemos?

recuento_sorted = recuento.sort_values(ascending=False)

recuento_sorted.head(10)
# Out:
# artist
# Bibi und Tina    10
# Juicy J          10
# Macklemore       10
# Ty Dolla sign     9
# Wu-Tang Clan      9
# DJ Khaled         9
# thasup            8
# B.o.B             8
# Wizkid            8
# Clean Bandit      8
# Name: track, dtype: int64

# %%
#¿Cuál es el número de canciones en los que ha colaborado el artista que ocupa el primer lugar en el *ranking*?

recuento_sorted.iloc[0]
# Out:
# np.int64(10)

# %%
#¿Cuál es el artista que ocupa el décimo lugar en el *ranking* y en cuántas canciones ha colaborado?
recuento_sorted.index[9]
# Out:
# 'Clean Bandit'
