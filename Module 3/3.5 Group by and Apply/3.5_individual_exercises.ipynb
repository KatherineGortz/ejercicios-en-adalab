# %% [markdown]
# 1. Total de unidades vendidas por país de origen del vendedor. Debéis agrupar los datos según el país de origen del vendedor y calcular el total de unidades vendidas para cada país. Esto nos dará una idea de qué países tienen una mayor participación en las ventas totales y cuáles tienen menos. Devuelve los resultados en un DataFrame ordenados de mayor a menor en función de la cantidad de unidades vendidas.

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("merchant_fill.csv", index_col = 0)

# %%
df.head(5)
# Out:
#                                                title  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...   8.00            22
# 2  Nouvelle mode d'été femmes robe décontractée c...   4.90             8
# 3   Summer Women s Fashion Lace Up Tie Pants Plus...   4.93             6
# 4  Nouvelle mode d'été femmes robe décontractée c...   5.65            10
#
#    units_sold  uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 0         100               0         3.76            54               26.0
# 1       20000               1         3.45          6135             2269.0
# 2        1000               1         3.83            99               43.0
# 3         100               0         3.77            47               22.0
# 4         100               1         2.86             7                1.0
#
#    rating_four_count  rating_three_count  rating_two_count  rating_one_count  \
# 0                8.0                10.0               1.0               9.0
# 1             1027.0              1118.0             644.0            1077.0
# 2               18.0                23.0               8.0               7.0
# 3                7.0                 8.0               5.0               5.0
# 4                1.0                 2.0               2.0               1.0
#
#    badge_local_product  badge_product_quality  badge_fast_shipping  \
# 0                    0                      0                    0
# 1                    0                      0                    0
# 2                    0                      0                    0
# 3                    0                      0                    0
# 4                    0                      0                    0
#
#                                                 tags product_color  \
# 0  Summer,Fashion,womenunderwearsuit,printedpajam...         white
# 1  Mini,womens dresses,Summer,Patchwork,fashion d...         green
# 2  Summer,Fashion,Necks,Beach,Dress,Loose,beach d...         white
# 3  Summer,Shorts,Lace,pants,Waist,Short pants,Yel...           red
# 4  Summer,Fashion,Necks,Skirts,Dress,Loose,Women'...         black
#
#   product_variation_size_id shipping_option_name  shipping_option_price  \
# 0                         M   Livraison standard                      4
# 1                        XS   Livraison standard                      2
# 2                       XXS   Livraison standard                      1
# 3                         S    Standard Shipping                      1
# 4                       XXS   Livraison standard                      1
#
#    shipping_is_express  countries_shipped_to  inventory_total origin_country  \
# 0                    0                    34               50             CN
# 1                    0                    41               50             CN
# 2                    0                    41               50             CN
# 3                    0                    41               50             CN
# 4                    0                    41               50             CN
#
#   merchant_name  merchant_info_subtitle  merchant_rating_count  \
# 0      zgrdejia                     NaN                    568
# 1     sarahouse     83 % avis positifs                   17752
# 2     sarahouse     83 % avis positifs                   17752
# 3     sarahouse  83% Positive Feedback                   17752
# 4     sarahouse     83 % avis positifs                   17752
#
#    merchant_rating               merchant_id  \
# 0         4.128521  595097d6a26f6e070cb878d1
# 1         3.899673  56458aa03a698c35c9050988
# 2         3.899673  56458aa03a698c35c9050988
# 3         3.899673  56458aa03a698c35c9050988
# 4         3.899673  56458aa03a698c35c9050988
#
#                                        product_url                product_id  \
# 0  https://www.wish.com/c/5e9ae51d43d6a96e303acdb0  5e9ae51d43d6a96e303acdb0
# 1  https://www.wish.com/c/58940d436a0d3d5da4e95a38  58940d436a0d3d5da4e95a38
# 2  https://www.wish.com/c/5df2576d68963c1660471f9a  5df2576d68963c1660471f9a
# 3  https://www.wish.com/c/5d58daef3159a812b05933d2  5d58daef3159a812b05933d2
# 4  https://www.wish.com/c/5e9fa7de39682a0043ab7898  5e9fa7de39682a0043ab7898
#
#    listed_products  total_units_sold  mean_units_sold_per_product  \
# 0                1               100                        100.0
# 1                6             21400                       3567.0
# 2                6             21400                       3567.0
# 3                6             21400                       3567.0
# 4                6             21400                       3567.0
#
#    rating_employee  merchant_ratings_count  mean_product_prices  \
# 0            4.129                   568.0                16.00
# 1            3.900                 17752.0                 5.68
# 2            3.900                 17752.0                 5.68
# 3            3.900                 17752.0                 5.68
# 4            3.900                 17752.0                 5.68
#
#    mean_retail_prices  average_discount  mean_discount  \
# 0               14.00             -14.0         -14.00
# 1               10.33              38.0          37.83
# 2               10.33              38.0          37.83
# 3               10.33              38.0          37.83
# 4               10.33              38.0          37.83
#
#    mean_product_ratings_count
# 0                        54.0
# 1                      1057.0
# 2                      1057.0
# 3                      1057.0
# 4                      1057.0

# %%
df['badge_local_product'].unique()
# Out:
# array([0, 1])

# %%
df.columns
# Out:
# Index(['title', 'price', 'retail_price', 'units_sold', 'uses_ad_boosts',
#        'rating_sold', 'rating_count', 'rating_five_count', 'rating_four_count',
#        'rating_three_count', 'rating_two_count', 'rating_one_count',
#        'badge_local_product', 'badge_product_quality', 'badge_fast_shipping',
#        'tags', 'product_color', 'product_variation_size_id',
#        'shipping_option_name', 'shipping_option_price', 'shipping_is_express',
#        'countries_shipped_to', 'inventory_total', 'origin_country',
#        'merchant_name', 'merchant_info_subtitle', 'merchant_rating_count',
#        'merchant_rating', 'merchant_id', 'product_url', 'product_id',
#        'listed_products', 'total_units_sold', 'mean_units_sold_per_product',
#        'rating_employee', 'merchant_ratings_count', 'mean_product_prices',
#        'mean_retail_prices', 'average_discount', 'mean_discount',
#        'mean_product_ratings_count'],
#       dtype='object')

# %%
df_group_country = df.groupby(by='origin_country')['units_sold'].count().reset_index()

df_sorted = df_group_country.sort_values(by='units_sold', ascending=False)

print(df_sorted)
# Out:
#   origin_country  units_sold
# 1             CN        1516
# 4             US          31
# 5             VE           5
# 3             SG           2
# 0             AT           1
# 2             GB           1

# %% [markdown]
# 2. Estadísticas de precio por país de envío. Vamos a explorar el precio promedio y el precio máximo de los productos según el país al que se envían. Al hacer esto, podremos entender cómo varían los precios según el destino del envío y si hay alguna tendencia interesante que valga la pena analizar. Devuelve los resultados en un DataFrame.

# %%
df2 = df.groupby(by='countries_shipped_to')['price'].mean()
df2
# Out:
# countries_shipped_to
# 6       6.000000
# 8       5.298333
# 9       6.707500
# 10     12.111429
# 11      8.500000
#          ...
# 135     5.355000
# 137     8.243333
# 138     6.036667
# 139     8.975000
# 140     5.220000
# Name: price, Length: 94, dtype: float64

# %%
df2b = df.groupby(by='countries_shipped_to')['price'].max()
df2b
# Out:
# countries_shipped_to
# 6       6.0
# 8       6.0
# 9       8.0
# 10     18.0
# 11     12.0
#        ...
# 135     7.0
# 137    11.0
# 138     9.0
# 139    13.0
# 140     7.0
# Name: price, Length: 94, dtype: float64

# %% [markdown]
# 3. Conteo de productos con y sin distintivo de producto local. Vamos a clasificar los productos según si tienen o no un distintivo de producto local. Luego, calcularemos el conteo de productos en cada categoría para comprender cuántos productos tienen este distintivo y cuántos no. Esto puede proporcionarnos información sobre cómo se promocionan los productos con esta característica. Devuelve los resultados en un DataFrame.

# %%
df_productos = df.groupby(by='badge_local_product' )['product_id'].count()

df_productos
# Out:
# badge_local_product
# 0    1544
# 1      29
# Name: product_id, dtype: int64

# %% [markdown]
# 4. Promedio de unidades vendidas por tipo de envío. Nuestro objetivo es analizar cómo se correlaciona el tipo de envío (columna shipping_option_name ) con las unidades vendidas. Vamos a calcular el promedio de unidades vendidas para cada tipo de opción de envío. Esto podría ayudarnos a determinar si ciertos métodos de envío están relacionados con un mayor o menor rendimiento en las ventas. Devuelve los resultados en un DataFrame. ¿Qué conclusiones puedes sacar de este resultado?

# %%
df_shipping = df.groupby(by='shipping_option_name')['units_sold'].mean()

df_shipping
# Out:
# shipping_option_name
# Ekspresowa wysyłka         10000.000000
# Envio Padrão                2488.888889
# Envío normal                3220.000000
# Expediere Standard           400.000000
# Livraison Express            400.000000
# Livraison standard          4383.756631
# Spedizione standard          550.000000
# Standard Shipping           4216.666667
# Standardowa wysyłka        10033.333333
# Standardversand              100.000000
# Standart Gönderi            5500.000000
# Стандартная доставка        3366.666667
# الشحن القياسي                325.000000
# การส่งสินค้ามาตรฐาน         5000.000000
# ការដឹកជញ្ជូនតាមស្តង់ដារ    10000.000000
# Name: units_sold, dtype: float64

# %% [markdown]
# Reemplazo de valores. A lo largo del DataFrame tenemos algunas columnas cuyos valores son cero y uno, lo que podría llevar a confusión en su interpretación. Estas columnas son:
#
# uses_ad_boosts: La cual indica si la plataforma de comercio electrónico ha utilizado o no la función de impulso de anuncios. Si el valor de uses_ad_boosts es 1, indica que el vendedor ha invertido en publicidad adicional para resaltar el producto. Si el valor es 0, no ha sido promocionado a través de anuncios adicionales.

# %%
diccionario_mapa = {0: "No", 1: "Si"}

df["uses_ad_boosts"] = df["uses_ad_boosts"].map(diccionario_mapa)

df.sample(3)
# Out:
#                                                   title  price  retail_price  \
# 1420  XS-8XL Plus Size Summer Women Casual Solid Col...    6.0             6
# 1095  2020 Plus La Taille S-5XL Dames À Manches Cour...    9.0             8
# 1121  Nouveau Femmes Mode Shorts D'été Yoga Shorts É...    8.0             7
#
#       units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 1420        5000             Si         4.13           616              341.0
# 1095         100             No         3.70            27               11.0
# 1121        1000             Si         2.98           108               36.0
#
#       rating_four_count  rating_three_count  rating_two_count  \
# 1420              125.0                74.0              39.0
# 1095                4.0                 6.0               5.0
# 1121                9.0                17.0               9.0
#
#       rating_one_count  badge_local_product  badge_product_quality  \
# 1420              37.0                    0                      0
# 1095               1.0                    0                      0
# 1121              37.0                    0                      0
#
#       badge_fast_shipping                                               tags  \
# 1420                    0  Mini,Fashion,halter dress,Summer,plus size dre...
# 1095                    0  Jeans,Plus Size,Sleeve,Summer,Dress,Denim,summ...
# 1121                    0  Summer,Beach Shorts,Yoga,Athletics,pants,casua...
#
#      product_color product_variation_size_id shipping_option_name  \
# 1420      navyblue                        XS   Livraison standard
# 1095          blue                        M.   Livraison standard
# 1121         green                         S   Livraison standard
#
#       shipping_option_price  shipping_is_express  countries_shipped_to  \
# 1420                      2                    0                    18
# 1095                      3                    0                    81
# 1121                      2                    0                    36
#
#       inventory_total origin_country    merchant_name merchant_info_subtitle  \
# 1420               50             CN     zktradecoltd    86 % avis positifs
# 1095               50             CN            fy251    85 % avis positifs
# 1121               50             CN  wushuangsciense    71 % avis positifs
#
#       merchant_rating_count  merchant_rating               merchant_id  \
# 1420                  15436         4.040555  5810b1db3deb94160f5cd4a3
# 1095                    104         3.894231  5d3e6e0ce13a7e7ae9f35f74
# 1121                    942         3.475584  5d46d6fd4c78550b43ab8351
#
#                                           product_url  \
# 1420  https://www.wish.com/c/5c8b7042b5154f67e6e2e327
# 1095  https://www.wish.com/c/5e6f204282e6d6b567d051d7
# 1121  https://www.wish.com/c/5e60a7a59c6112c4c01a2ded
#
#                     product_id  listed_products  total_units_sold  \
# 1420  5c8b7042b5154f67e6e2e327                1              5000
# 1095  5e6f204282e6d6b567d051d7                2               200
# 1121  5e60a7a59c6112c4c01a2ded                2              2000
#
#       mean_units_sold_per_product  rating_employee  merchant_ratings_count  \
# 1420                       5000.0            4.041                 15436.0
# 1095                        100.0            3.894                   104.0
# 1121                       1000.0            3.476                   942.0
#
#       mean_product_prices  mean_retail_prices  average_discount  \
# 1420                  6.0                 6.0               0.0
# 1095                  9.0                 8.0             -12.0
# 1121                  8.0                 7.0             -14.0
#
#       mean_discount  mean_product_ratings_count
# 1420            0.0                       616.0
# 1095          -12.0                        27.0
# 1121          -14.0                        86.0

# %% [markdown]
# badge_local_product: Indica que el producto se produce, fabrica o se envía desde la misma región o país en el que se realiza la transacción de compra. Si el valor es 1, significa que el producto tiene un distintivo que lo califica como un producto local. Si el valor es 0, indica que el producto no tiene este distintivo.

# %%
df.dtypes
# Out:
# title                           object
# price                          float64
# retail_price                     int64
# units_sold                       int64
# uses_ad_boosts                  object
# rating_sold                    float64
# rating_count                     int64
# rating_five_count              float64
# rating_four_count              float64
# rating_three_count             float64
# rating_two_count               float64
# rating_one_count               float64
# badge_local_product              int64
# badge_product_quality            int64
# badge_fast_shipping              int64
# tags                            object
# product_color                   object
# product_variation_size_id       object
# shipping_option_name            object
# shipping_option_price            int64
# shipping_is_express              int64
# countries_shipped_to             int64
# inventory_total                  int64
# origin_country                  object
# merchant_name                   object
# merchant_info_subtitle          object
# merchant_rating_count            int64
# merchant_rating                float64
# merchant_id                     object
# product_url                     object
# product_id                      object
# listed_products                  int64
# total_units_sold                 int64
# mean_units_sold_per_product    float64
# rating_employee                float64
# merchant_ratings_count         float64
# mean_product_prices            float64
# mean_retail_prices             float64
# average_discount               float64
# mean_discount                  float64
# mean_product_ratings_count     float64
# dtype: object

# %%
df['badge_local_product'].unique()
# Out:
# array([0, 1])

# %%
diccionario_mapa = {0: "No", 1: "Si"}

df["badge_local_product"] = df["badge_local_product"].map(diccionario_mapa)
df.sample(3)
# Out:
#                                                  title  price  retail_price  \
# 633  Summer New Fashion Women Two Pieces Sleepwear ...   8.00             7
# 865  Nouveau Sexy Femmes Bandage Découpé Débardeurs...   5.67             5
# 240  Mode féminine Printemps et été O-cou T-shirt e...   5.00             5
#
#      units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 633         100             Si         3.86            28               14.0
# 865       20000             No         3.63          7242             2867.0
# 240        1000             Si         4.13           103               59.0
#
#      rating_four_count  rating_three_count  rating_two_count  \
# 633                4.0                 5.0               2.0
# 865             1406.0              1330.0             695.0
# 240               18.0                14.0               4.0
#
#      rating_one_count badge_local_product  badge_product_quality  \
# 633               3.0                  No                      0
# 865             944.0                  No                      0
# 240               8.0                  No                      0
#
#      badge_fast_shipping                                               tags  \
# 633                    0  pajamaset,Fashion,sexy pajamas for womens,silk...
# 865                    0  Summer,sportytankini,crop top,Tank,Tops,tank t...
# 240                    0  blouse,Summer,Plus Size,Cotton,Shirt,Sleeve,Sp...
#
#     product_color product_variation_size_id shipping_option_name  \
# 633           red                        XS   Livraison standard
# 865         white                       NaN   Livraison standard
# 240       winered                         S   Livraison standard
#
#      shipping_option_price  shipping_is_express  countries_shipped_to  \
# 633                      3                    0                    28
# 865                      1                    0                    40
# 240                      2                    0                    48
#
#      inventory_total origin_country merchant_name merchant_info_subtitle  \
# 633               50             CN       fangyin    91 % avis positifs
# 865               50            NaN   fashionshow    87 % avis positifs
# 240               50             CN   广州唯适唯服饰有限公司    83 % avis positifs
#
#      merchant_rating_count  merchant_rating               merchant_id  \
# 633                    889         4.390326  583beacf24b24f1b805ff7a2
# 865                 839882         4.103760  52bd3ddb34067e4620a4c62d
# 240                  32168         3.884544  558c2cdc89d53c4005ea2920
#
#                                          product_url  \
# 633  https://www.wish.com/c/5d832e8bdfe9c5124cb98bd2
# 865  https://www.wish.com/c/5801bf9ef22bef78458987d8
# 240  https://www.wish.com/c/5e8d78b38a5fed4a5a026712
#
#                    product_id  listed_products  total_units_sold  \
# 633  5d832e8bdfe9c5124cb98bd2                2               200
# 865  5801bf9ef22bef78458987d8                3             80000
# 240  5e8d78b38a5fed4a5a026712               15             58500
#
#      mean_units_sold_per_product  rating_employee  merchant_ratings_count  \
# 633                        100.0            4.390                   889.0
# 865                      26667.0            4.104                839882.0
# 240                       3900.0            3.885                 32168.0
#
#      mean_product_prices  mean_retail_prices  average_discount  mean_discount  \
# 633                 8.00                7.00             -14.0         -14.00
# 865                 7.22               14.67              33.0          33.33
# 240                 4.18                4.13               1.0           1.20
#
#      mean_product_ratings_count
# 633                        28.0
# 865                      6136.0
# 240                       749.0

# %%
df['badge_local_product'].unique()
# Out:
# array(['No', 'Si'], dtype=object)

# %% [markdown]
# badge_product_quality: Indica que el producto cumple con ciertos estándares de calidad, características o evaluaciones positivas por parte de los consumidores. Si el valor es 1, significa que el producto tiene un distintivo que lo califica como un producto de alta calidad. Si el valor es 0, indica que el producto no tiene este distintivo de calidad.

# %%
diccionario_mapa = {"No_Calidad": 'No', "Calidad": 'Yes'}

df["badge_product_quality"] = df["badge_product_quality"].map(diccionario_mapa)
df.sample(3)
# Out:
#                                                   title  price  retail_price  \
# 395   Sexy Women's Summer Casual Sleeveless Evening ...    5.0             8
# 1006  UR SUGAR 4 Bouteilles / Set Coloré Kit de Vern...    7.0             6
# 902   S-XXL Mode Eté Printemps Femme Elastique Taill...   12.0            81
#
#       units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 395         1000             Si         3.06            31                9.0
# 1006         100             Si         4.57            23               16.0
# 902        20000             No         4.08          1799              960.0
#
#       rating_four_count  rating_three_count  rating_two_count  \
# 395                 5.0                 5.0               3.0
# 1006                4.0                 3.0               0.0
# 902               346.0               285.0              97.0
#
#       rating_one_count badge_local_product badge_product_quality  \
# 395                9.0                  No                    No
# 1006               0.0                  No                   Yes
# 902              111.0                  No                    No
#
#      badge_fast_shipping                                               tags  \
# 395       Sin_distintivo  Mini,womens dresses,Summer,Patchwork,fashion d...
# 1006      Sin_distintivo  Summer,Colorful,Beauty,Nail Polish,nail kit,ma...
# 902       Sin_distintivo  Shorts,Lace,pants,Dress,Women Leggings,Hot pan...
#
#      product_color    product_variation_size_id shipping_option_name  \
# 395      mintgreen                          XXS   Livraison standard
# 1006           NaN  Base & Top & Matte Top Coat   Livraison standard
# 902          white                            M   Livraison standard
#
#       shipping_option_price shipping_is_express  countries_shipped_to  \
# 395                       1                  No                    40
# 1006                      2                  No                    27
# 902                       3                  No                    38
#
#       inventory_total origin_country    merchant_name merchant_info_subtitle  \
# 395                50             CN       hillntrees    83 % avis positifs
# 1006               50             CN       spaklestar    93 % avis positifs
# 902                50             CN  guangzhouchanny    88 % avis positifs
#
#       merchant_rating_count  merchant_rating               merchant_id  \
# 395                    8484         3.995167  5700e2be27992f63cdca2dca
# 1006                 105684         4.430936  5742c706d75bc459506b80f1
# 902                  151914         4.127921  53aa664438d3046ee44a5024
#
#                                           product_url  \
# 395   https://www.wish.com/c/5e9e8180ec24302643422eff
# 1006  https://www.wish.com/c/5e7e0c35e27371898f419f5d
# 902   https://www.wish.com/c/53c8f05046188e57778ac77c
#
#                     product_id  listed_products  total_units_sold  \
# 395   5e9e8180ec24302643422eff                1              1000
# 1006  5e7e0c35e27371898f419f5d                1               100
# 902   53c8f05046188e57778ac77c                4             60100
#
#       mean_units_sold_per_product  rating_employee  merchant_ratings_count  \
# 395                        1000.0            3.995                  8484.0
# 1006                        100.0            4.431                105684.0
# 902                       15025.0            4.128                151914.0
#
#       mean_product_prices  mean_retail_prices  average_discount  \
# 395                   5.0                 8.0              38.0
# 1006                  7.0                 6.0             -16.0
# 902                  12.5                83.0              86.0
#
#       mean_discount  mean_product_ratings_count
# 395            38.0                        31.0
# 1006          -16.0                        23.0
# 902            85.5                      2517.0

# %% [markdown]
# badge_fast_shipping: Indica que el producto se enviará y entregará en un plazo más corto en comparación con otras opciones de envío estándar. Si el valor es 1, significa que el producto tiene un distintivo que indica un envío rápido. Si el valor es 0, indica que el producto no tiene este distintivo de envío rápido.

# %%
diccionario_mapa = {0: "Sin_distintivo", 1: "Distinto_envio_rapido"}

df["badge_fast_shipping"] = df["badge_fast_shipping"].map(diccionario_mapa)
df.sample(3)
# Out:
#                                                   title  price  retail_price  \
# 1151  Femmes Casual Hippie Lettre Imprimé Robe Longu...   6.00            11
# 213   7 Couleurs Top 2018 Femme Femme Femme Sexy Top...   5.77             5
# 1368  T-shirts décontractés d'été Tube d'épaule uniq...   4.00             4
#
#       units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 1151         100             No         4.00            35               21.0
# 213          100             Si         4.00             4                1.0
# 1368        1000             No         3.51           550              215.0
#
#       rating_four_count  rating_three_count  rating_two_count  \
# 1151                5.0                 2.0               2.0
# 213                 2.0                 1.0               0.0
# 1368               99.0                86.0              53.0
#
#       rating_one_count badge_local_product badge_product_quality  \
# 1151               5.0                  No            No_Calidad
# 213                0.0                  No            No_Calidad
# 1368              97.0                  No            No_Calidad
#
#      badge_fast_shipping                                               tags  \
# 1151      Sin_distintivo  Summer,A-line,women dresses,long dress,Dress,s...
# 213       Sin_distintivo  blouse,Summer,Vest,Plus Size,Tank,Lace,Women S...
# 1368      Sin_distintivo  Summer,Vest,Fashion,Yoga,woman vest,girl bra,T...
#
#      product_color product_variation_size_id shipping_option_name  \
# 1151     armygreen                       XXS   Livraison standard
# 213      armygreen                         S   Livraison standard
# 1368         green                        XS   Livraison standard
#
#       shipping_option_price  shipping_is_express  countries_shipped_to  \
# 1151                      2                    0                    25
# 213                       1                    0                    31
# 1368                      1                    0                    32
#
#       inventory_total origin_country    merchant_name merchant_info_subtitle  \
# 1151               50             CN       lianhaiqin    80 % avis positifs
# 213                50             CN  hufscfshkuhjdfs                    NaN
# 1368               50             CN          allofme    90 % avis positifs
#
#       merchant_rating_count  merchant_rating               merchant_id  \
# 1151                   3245         3.774114  59510a44905fdb0b8266ddc5
# 213                    8996         3.915740  5b348167af6b3122dba38825
# 1368                  13884         4.222846  5788a55ba78e3f2dce4126ff
#
#                                           product_url  \
# 1151  https://www.wish.com/c/5e7ee69fa9d2ef00550fedaf
# 213   https://www.wish.com/c/5ec773b5967eb036b2c2e668
# 1368  https://www.wish.com/c/5c3fe7021a62f63f6d4820ef
#
#                     product_id  listed_products  total_units_sold  \
# 1151  5e7ee69fa9d2ef00550fedaf                1               100
# 213   5ec773b5967eb036b2c2e668                2               200
# 1368  5c3fe7021a62f63f6d4820ef                2              6000
#
#       mean_units_sold_per_product  rating_employee  merchant_ratings_count  \
# 1151                        100.0            3.774                  3245.0
# 213                         100.0            3.916                  8996.0
# 1368                       3000.0            4.223                 13884.0
#
#       mean_product_prices  mean_retail_prices  average_discount  \
# 1151                 6.00                11.0              46.0
# 213                  5.77                 5.0             -15.0
# 1368                 3.50                 3.5               0.0
#
#       mean_discount  mean_product_ratings_count
# 1151           46.0                        35.0
# 213           -15.0                         4.0
# 1368            0.0                       858.0

# %% [markdown]
# shipping_is_express: Se refiere a si una opción de envío para un producto en una plataforma de comercio electrónico se considera como "envío exprés" o "envío rápido". Si el valor es 1, significa que la opción de envío asociada se considera como una entrega rápida o exprés. Si el valor es 0, indica que la opción de envío no se considera como envío exprés.

# %%
diccionario_mapa = {0: "No", 1: "Yes"}

df["shipping_is_express"] = df["shipping_is_express"].map(diccionario_mapa)
df.sample(3)
# Out:
#                                                   title  price  retail_price  \
# 1001  Pantalon à lacets à la mode pour femmes d'été,...    5.0            30
# 1160  2020 nouveau 3 couleurs mode femmes pantoufles...    9.0             8
# 23    Robe à bretelles lâche col en v pour femmes d'...    7.0            26
#
#       units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 1001         100             No         3.69            13                5.0
# 1160         100             Si         4.13            23               13.0
# 23         10000             No         3.86          2092             1009.0
#
#       rating_four_count  rating_three_count  rating_two_count  \
# 1001                2.0                 4.0               1.0
# 1160                4.0                 4.0               0.0
# 23                399.0               300.0             143.0
#
#       rating_one_count badge_local_product badge_product_quality  \
# 1001               1.0                  No            No_Calidad
# 1160               2.0                  No            No_Calidad
# 23               241.0                  No            No_Calidad
#
#      badge_fast_shipping                                               tags  \
# 1001      Sin_distintivo  Summer,Shorts,high waist shorts,Lace,Casual pa...
# 1160      Sin_distintivo  heightenedshoe,wedge,Sandals,casual shoes,High...
# 23        Sin_distintivo  Summer,Lace,Dress,Lace Dress,V-neck,Women's Fa...
#
#      product_color product_variation_size_id shipping_option_name  \
# 1001         black                        XS   Livraison standard
# 1160         black                        33   Livraison standard
# 23           white                         S   Livraison standard
#
#       shipping_option_price shipping_is_express  countries_shipped_to  \
# 1001                      1                  No                    40
# 1160                      3                  No                    47
# 23                        2                  No                    33
#
#       inventory_total origin_country   merchant_name merchant_info_subtitle  \
# 1001               50            NaN  topmanclothing                    NaN
# 1160               50             CN    rmslkfgylove                    NaN
# 23                 50             CN    luoweiclothe    85 % avis positifs
#
#       merchant_rating_count  merchant_rating               merchant_id  \
# 1001                  16215         3.840025  52838e612dcc6469fa2d7104
# 1160                   3769         4.239851  5aa5d06da6bf7a7f7285bc0e
# 23                     5534         3.999819  5ba2251b4315d12ebce873fa
#
#                                           product_url  \
# 1001  https://www.wish.com/c/5e44564413b8939de2f0a0f8
# 1160  https://www.wish.com/c/5ed213d6342ca33d87fe2ea4
# 23    https://www.wish.com/c/5cc5363ab90e2b5649a53b80
#
#                     product_id  listed_products  total_units_sold  \
# 1001  5e44564413b8939de2f0a0f8                2               200
# 1160  5ed213d6342ca33d87fe2ea4                1               100
# 23    5cc5363ab90e2b5649a53b80                5             22000
#
#       mean_units_sold_per_product  rating_employee  merchant_ratings_count  \
# 1001                        100.0             3.84                 16215.0
# 1160                        100.0             4.24                  3769.0
# 23                         4400.0             4.00                  5534.0
#
#       mean_product_prices  mean_retail_prices  average_discount  \
# 1001                 5.00                30.0              84.0
# 1160                 9.00                 8.0             -12.0
# 23                   8.36                25.2              68.0
#
#       mean_discount  mean_product_ratings_count
# 1001           84.0                        13.0
# 1160          -12.0                        23.0
# 23             67.6                       930.0

# %% [markdown]
# 6. Calificación de la calidad del producto. Sobreescribe la columna badge_product_quality utilizando apply() para asignar "Buena" a las filas donde 'badge_product_quality' sea "No" y "Excelente" donde sea "Si".

# %%
def assign_badge(quality):
    if quality =='Yes':
        return "Buena"
    else:
        return "Excelente"

# %%
df["badge_product_quality"] =df["badge_product_quality"].apply(assign_badge)

# %%
df["badge_product_quality"].unique()
# Out:
# array(['Excelente', 'Buena'], dtype=object)

# %% [markdown]
# 7. Cálculo de descuento. Crea una nueva columna discount_percentage utilizando apply() que calcule el porcentaje de descuento basado en las columnas 'price' y 'retail_price', redondea los decimales a 2. Después elimina las columnas de average_discount y mean_discount

# %%
df['discount_percentage'] = ((df['retail_price'] - df['price']) / df['retail_price'] * 100).round(2)

df.drop(['average_discount', 'mean_discount'], axis=1, inplace=True)

# %%
df.sample(5)
# Out:
#                                                   title  price  retail_price  \
# 651   2019 été femmes robe florale impression hors é...    9.0             8
# 432   Été Nouveau Design De Mode Femmes Sans Manches...    6.0            13
# 1483  S-5XL Plus La Taille D'été De Mode Femmes Sans...    8.0           252
# 1303  Pyjama mignon ensemble rose bugs lapin dessin ...    9.0            49
# 276   Nouvelles femmes de mode robe d'été imprimé fl...    7.0             6
#
#       units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 651          100             No         4.07            27               14.0
# 432         1000             No         3.26           255               87.0
# 1483        1000             Si         3.88           161               79.0
# 1303         100             Si         3.72           109               51.0
# 276         1000             Si         4.20           107               66.0
#
#       rating_four_count  rating_three_count  rating_two_count  \
# 651                 8.0                 1.0               1.0
# 432                36.0                44.0              32.0
# 1483               23.0                34.0              10.0
# 1303               14.0                21.0               9.0
# 276                13.0                18.0               3.0
#
#       rating_one_count badge_local_product badge_product_quality  \
# 651                3.0                  No             Excelente
# 432               56.0                  No             Excelente
# 1483              15.0                  No             Excelente
# 1303              14.0                  No             Excelente
# 276                7.0                  No             Excelente
#
#      badge_fast_shipping                                               tags  \
# 651       Sin_distintivo  Mini,Lace Dress,Lace,Summer,Dress,Mini dress,W...
# 432       Sin_distintivo  tank top women,Vest,Fashion,buttontop,Summer,L...
# 1483      Sin_distintivo  gowns,Plus Size,pleated dress,Vintage Dresses,...
# 1303      Sin_distintivo  pink,Summer,Polyester,Shorts,Set,cute,printing...
# 276       Sin_distintivo  Summer,Plus Size,Dress,Spaghetti Strap,Ladies,...
#
#      product_color product_variation_size_id shipping_option_name  \
# 651         yellow                         M   Livraison standard
# 432           wine                         S   Livraison standard
# 1483         black                        XS   Livraison standard
# 1303          pink                         M   Livraison standard
# 276          white                        XS   Livraison standard
#
#       shipping_option_price shipping_is_express  countries_shipped_to  \
# 651                       3                  No                    22
# 432                       2                  No                    43
# 1483                      3                  No                    41
# 1303                      3                  No                    36
# 276                       2                  No                    26
#
#       inventory_total origin_country    merchant_name merchant_info_subtitle  \
# 651                50             US        arthumcco    92 % avis positifs
# 432                50             CN  zoushoujintmiao    88 % avis positifs
# 1483               50             CN           legeit    83 % avis positifs
# 1303               50             CN        huajitoup    88 % avis positifs
# 276                50             CN      alabaostore    83 % avis positifs
#
#       merchant_rating_count  merchant_rating               merchant_id  \
# 651                   34975         4.336583  582c712cae088637843348a5
# 432                    3161         4.181588  5ae56280ddf45b183333ac45
# 1483                  14780         3.950812  56961502ca1588618ca6d5fe
# 1303                    267         4.041199  5b4973b049c8e64e07c31cb4
# 276                     247         3.943320  5d5256c527752b19063d8c53
#
#                                           product_url  \
# 651   https://www.wish.com/c/5d26a954b93be477634336ab
# 432   https://www.wish.com/c/5e227b0fca2543070a2e1734
# 1483  https://www.wish.com/c/5ae978af2d88f95727d921f2
# 1303  https://www.wish.com/c/5d42a8479ef2d22e268e050a
# 276   https://www.wish.com/c/5e9915ef9fae4f26f32f15df
#
#                     product_id  listed_products  total_units_sold  \
# 651   5d26a954b93be477634336ab                1               100
# 432   5e227b0fca2543070a2e1734                2              2000
# 1483  5ae978af2d88f95727d921f2                1              1000
# 1303  5d42a8479ef2d22e268e050a                1               100
# 276   5e9915ef9fae4f26f32f15df                5              2300
#
#       mean_units_sold_per_product  rating_employee  merchant_ratings_count  \
# 651                         100.0            4.337                 34975.0
# 432                        1000.0            4.182                  3161.0
# 1483                       1000.0            3.951                 14780.0
# 1303                        100.0            4.041                   267.0
# 276                         460.0            3.943                   247.0
#
#       mean_product_prices  mean_retail_prices  mean_product_ratings_count  \
# 651                  9.00                 8.0                        27.0
# 432                  5.87                36.0                       163.0
# 1483                 8.00               252.0                       161.0
# 1303                 9.00                49.0                       109.0
# 276                  7.53                 6.8                        51.0
#
#       discount_percentage
# 651                -12.50
# 432                 53.85
# 1483                96.83
# 1303                81.63
# 276                -16.67

# %% [markdown]
# 8. Evaluación de la valoración del vendedor. Utiliza apply() para crear una nueva columna 'seller_reputation' donde los valores sean "Buena" si 'merchant_rating' es mayor o igual a 4, y "Regular" si es menor a 4. Después elimina la columna merchant_rating.

# %%
def seller_rep(rating):
    if rating >= 4:
        return 'Buena'
    elif rating < 4:
        return 'Regular'
    
df['seller_reputation']=df['merchant_rating'].apply(seller_rep)

# %%
df
# Out:
#                                                   title  price  retail_price  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1     SSHOUSE Summer Casual Sleeveless Soirée Party ...   8.00            22
# 2     Nouvelle mode d'été femmes robe décontractée c...   4.90             8
# 3      Summer Women s Fashion Lace Up Tie Pants Plus...   4.93             6
# 4     Nouvelle mode d'été femmes robe décontractée c...   5.65            10
# ...                                                 ...    ...           ...
# 1568  Mode d'été pour dames Jumpsuit sans manches im...  13.00            11
# 1569  Chemises d'été pour femmes Plus col en V sans ...   7.00            25
# 1570  Plus la taille nouvelle mode féminine d'été co...   3.87             4
# 1571  Nouveautés Hommes Siwmwear Beach-Shorts Hommes...   5.00            19
# 1572  Pantalon de yoga pour femmes à la mode Slim Fi...   7.00             6
#
#       units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 0            100             No         3.76            54               26.0
# 1          20000             Si         3.45          6135             2269.0
# 2           1000             Si         3.83            99               43.0
# 3            100             No         3.77            47               22.0
# 4            100             Si         2.86             7                1.0
# ...          ...            ...          ...           ...                ...
# 1568       10000             No         4.12          2901             1573.0
# 1569        5000             No         3.50           774              258.0
# 1570        1000             Si         3.68            62               28.0
# 1571         100             No         3.71            59               24.0
# 1572         100             Si         4.07            14                8.0
#
#       rating_four_count  rating_three_count  rating_two_count  \
# 0                   8.0                10.0               1.0
# 1                1027.0              1118.0             644.0
# 2                  18.0                23.0               8.0
# 3                   7.0                 8.0               5.0
# 4                   1.0                 2.0               2.0
# ...                 ...                 ...               ...
# 1568              606.0               399.0             135.0
# 1569              176.0               147.0              81.0
# 1570               11.0                 7.0               7.0
# 1571               15.0                 8.0               3.0
# 1572                3.0                 1.0               0.0
#
#       rating_one_count badge_local_product badge_product_quality  \
# 0                  9.0                  No             Excelente
# 1               1077.0                  No             Excelente
# 2                  7.0                  No             Excelente
# 3                  5.0                  No             Excelente
# 4                  1.0                  No             Excelente
# ...                ...                 ...                   ...
# 1568             188.0                  No             Excelente
# 1569             112.0                  No             Excelente
# 1570               9.0                  No             Excelente
# 1571               9.0                  No             Excelente
# 1572               2.0                  No             Excelente
#
#      badge_fast_shipping                                               tags  \
# 0         Sin_distintivo  Summer,Fashion,womenunderwearsuit,printedpajam...
# 1         Sin_distintivo  Mini,womens dresses,Summer,Patchwork,fashion d...
# 2         Sin_distintivo  Summer,Fashion,Necks,Beach,Dress,Loose,beach d...
# 3         Sin_distintivo  Summer,Shorts,Lace,pants,Waist,Short pants,Yel...
# 4         Sin_distintivo  Summer,Fashion,Necks,Skirts,Dress,Loose,Women'...
# ...                  ...                                                ...
# 1568      Sin_distintivo  Summer,trousers,Floral print,Fashion,Print,Lon...
# 1569      Sin_distintivo  shirtsforwomen,Summer,Fashion,Tops & Blouses,S...
# 1570      Sin_distintivo  Summer,Plus Size,tunic,Tops,blousetop,Casual,W...
# 1571      Sin_distintivo  runningshort,Beach Shorts,beachpant,menbeachsh...
# 1572      Sin_distintivo  Summer,Leggings,slim,Yoga,pants,Slim Fit,Women...
#
#      product_color product_variation_size_id shipping_option_name  \
# 0            white                         M   Livraison standard
# 1            green                        XS   Livraison standard
# 2            white                       XXS   Livraison standard
# 3              red                         S    Standard Shipping
# 4            black                       XXS   Livraison standard
# ...            ...                       ...                  ...
# 1568         black                         M   Livraison standard
# 1569      burgundy                         S   Livraison standard
# 1570         green                        XS   Livraison standard
# 1571         white                    SIZE S   Livraison standard
# 1572           red                         S   Livraison standard
#
#       shipping_option_price shipping_is_express  countries_shipped_to  \
# 0                         4                  No                    34
# 1                         2                  No                    41
# 2                         1                  No                    41
# 3                         1                  No                    41
# 4                         1                  No                    41
# ...                     ...                 ...                   ...
# 1568                      3                  No                    36
# 1569                      2                  No                    27
# 1570                      1                  No                    40
# 1571                      2                  No                    11
# 1572                      2                  No                    41
#
#       inventory_total origin_country   merchant_name  merchant_info_subtitle  \
# 0                  50             CN        zgrdejia                     NaN
# 1                  50             CN       sarahouse     83 % avis positifs
# 2                  50             CN       sarahouse     83 % avis positifs
# 3                  50             CN       sarahouse  83% Positive Feedback
# 4                  50             CN       sarahouse     83 % avis positifs
# ...               ...            ...             ...                     ...
# 1568               50             CN        teamwolf                     NaN
# 1569               50             CN        anqiyila     89 % avis positifs
# 1570               50             CN       zhuanta1e     75 % avis positifs
# 1571               50             CN      shixueying     86 % avis positifs
# 1572               50             CN  aishoppingmall     90 % avis positifs
#
#       merchant_rating_count  merchant_rating               merchant_id  \
# 0                       568         4.128521  595097d6a26f6e070cb878d1
# 1                     17752         3.899673  56458aa03a698c35c9050988
# 2                     17752         3.899673  56458aa03a698c35c9050988
# 3                     17752         3.899673  56458aa03a698c35c9050988
# 4                     17752         3.899673  56458aa03a698c35c9050988
# ...                     ...              ...                       ...
# 1568                  14502         4.147842  56c3c5d830d9795c3bad3124
# 1569                  11680         4.192894  58f0a6738a60c363c1281d72
# 1570                    265         3.626415  5d3d857c0ff7f937558c4dd1
# 1571                    210         3.961905  5b42da1bf64320209fc8da69
# 1572                   7023         4.235939  5a409cf87b584e7951b2e25f
#
#                                           product_url  \
# 0     https://www.wish.com/c/5e9ae51d43d6a96e303acdb0
# 1     https://www.wish.com/c/58940d436a0d3d5da4e95a38
# 2     https://www.wish.com/c/5df2576d68963c1660471f9a
# 3     https://www.wish.com/c/5d58daef3159a812b05933d2
# 4     https://www.wish.com/c/5e9fa7de39682a0043ab7898
# ...                                               ...
# 1568  https://www.wish.com/c/5a6ac97e5983516f0f0dbf85
# 1569  https://www.wish.com/c/5ccea5c767c5606e6f8022b1
# 1570  https://www.wish.com/c/5e60eee21ed938ec8c3da0af
# 1571  https://www.wish.com/c/5e74be96034d613d42b52dfe
# 1572  https://www.wish.com/c/5e857321f53c3d2d8f25e7ed
#
#                     product_id  listed_products  total_units_sold  \
# 0     5e9ae51d43d6a96e303acdb0                1               100
# 1     58940d436a0d3d5da4e95a38                6             21400
# 2     5df2576d68963c1660471f9a                6             21400
# 3     5d58daef3159a812b05933d2                6             21400
# 4     5e9fa7de39682a0043ab7898                6             21400
# ...                        ...              ...               ...
# 1568  5a6ac97e5983516f0f0dbf85                1             10000
# 1569  5ccea5c767c5606e6f8022b1                1              5000
# 1570  5e60eee21ed938ec8c3da0af                1              1000
# 1571  5e74be96034d613d42b52dfe                1               100
# 1572  5e857321f53c3d2d8f25e7ed                1               100
#
#       mean_units_sold_per_product  rating_employee  merchant_ratings_count  \
# 0                           100.0            4.129                   568.0
# 1                          3567.0            3.900                 17752.0
# 2                          3567.0            3.900                 17752.0
# 3                          3567.0            3.900                 17752.0
# 4                          3567.0            3.900                 17752.0
# ...                           ...              ...                     ...
# 1568                      10000.0            4.148                 14502.0
# 1569                       5000.0            4.193                 11680.0
# 1570                       1000.0            3.626                   265.0
# 1571                        100.0            3.962                   210.0
# 1572                        100.0            4.236                  7023.0
#
#       mean_product_prices  mean_retail_prices  mean_product_ratings_count  \
# 0                   16.00               14.00                        54.0
# 1                    5.68               10.33                      1057.0
# 2                    5.68               10.33                      1057.0
# 3                    5.68               10.33                      1057.0
# 4                    5.68               10.33                      1057.0
# ...                   ...                 ...                         ...
# 1568                13.00               11.00                      2901.0
# 1569                 7.00               25.00                       774.0
# 1570                 3.87                4.00                        62.0
# 1571                 5.00               19.00                        59.0
# 1572                 7.00                6.00                        14.0
#
#       discount_percentage seller_reputation
# 0                  -14.29             Buena
# 1                   63.64           Regular
# 2                   38.75           Regular
# 3                   17.83           Regular
# 4                   43.50           Regular
# ...                   ...               ...
# 1568               -18.18             Buena
# 1569                72.00             Buena
# 1570                 3.25           Regular
# 1571                73.68           Regular
# 1572               -16.67             Buena
#
# [1573 rows x 41 columns]
