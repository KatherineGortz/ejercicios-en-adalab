# %%
import pandas as pd

# %% [markdown]
# i download this dataset on opensourse website.
#
# This data set is all about Real or Fake News or Text dataset.
# Here are only 4 columns.
# number:
# title:
# text:
# label:
# This is all about this dataset.
#
# URL: https://www.kaggle.com/datasets/jillanisofttech/fake-or-real-news

# %%
df_dataset_1 = pd.read_csv(r'C:\Users\Kathe\Documents\source_code\ejercicios-en-adalab\Proyecto Personal\DATASET 1\DATASET1 fake_or_real_news.csv')

pd.set_option('display.max_columns', None)

df_dataset_1
# Out:
#       Unnamed: 0                                              title  \
# 0           8476                       You Can Smell Hillary’s Fear
# 1          10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2           3608        Kerry to go to Paris in gesture of sympathy
# 3          10142  Bernie supporters on Twitter erupt in anger ag...
# 4            875   The Battle of New York: Why This Primary Matters
# ...          ...                                                ...
# 6330        4490  State Department says it can't find emails fro...
# 6331        8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332        8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333        4021  In Ethiopia, Obama seeks progress on peace, se...
# 6334        4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# ...

# %%
print(f'There are {df_dataset_1.shape[0]} rows in Dataset1')
print(f'There are {df_dataset_1.shape[1]} columns in Dataset1')
# Out:
# There are 6335 rows in Dataset1
# There are 4 columns in Dataset1

# %%
df_dataset_1.describe().T
# Out:
#              count         mean          std  min     25%     50%     75%  \
# Unnamed: 0  6335.0  5280.415627  3038.503953  2.0  2674.5  5271.0  7901.0
#
#                 max
# Unnamed: 0  10557.0

# %%
df_dataset_1.describe(include = 'object').T
# Out:
#       count unique                                                top  freq
# title  6335   6256                      OnPolitics | 's politics blog     5
# text   6335   6060  Killing Obama administration rules, dismantlin...    58
# label  6335      2                                               REAL  3171

# %%
df_dataset_1['title'].unique()
# Out:
# array(['You Can Smell Hillary’s Fear',
#        'Watch The Exact Moment Paul Ryan Committed Political Suicide At A Trump Rally (VIDEO)',
#        'Kerry to go to Paris in gesture of sympathy', ...,
#        'Anti-Trump Protesters Are Tools of the Oligarchy     : Information',
#        'In Ethiopia, Obama seeks progress on peace, security in East Africa',
#        "Jeb Bush Is Suddenly Attacking Trump. Here's Why That Matters"],
#       shape=(6256,), dtype=object)

# %%
df_dataset_1.dtypes
# Out:
# Unnamed: 0     int64
# title         object
# text          object
# label         object
# dtype: object

# %%
df_dataset_1['label'].value_counts()
# Out:
# label
# REAL    3171
# FAKE    3164
# Name: count, dtype: int64

# %%
df_dataset_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6335 entries, 0 to 6334
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  6335 non-null   int64
#  1   title       6335 non-null   object
#  2   text        6335 non-null   object
#  3   label       6335 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 198.1+ KB

# %%
duplicates_df_1 = df_dataset_1[df_dataset_1.duplicated(subset= ['title', 'text'])]


duplicates_df_1
# Out:
#       Unnamed: 0                                              title  \
# 1492        2697  University of Missouri, please immediately fir...
# 1954        4544  Loretta Lynch becomes first African-American w...
# 2336        4396  Obamacare Enrollees Anxiously Await Supreme Co...
# 2856        2664  Donald Trump is blatantly racist — and the med...
# 2952        7550       Black Agenda Report for Week of Oct 31, 2016
# 3081        4160    The College Loan Bombshell Hidden in the Budget
# 3292        3056  This astonishing chart shows how moderate Repu...
# 3301        1762                      OnPolitics | 's politics blog
# 3324        2399  Senate GOP prepared to replace Obamacare subsi...
# 4140        2261  We Republicans Lost On Gay Rights. That’s A Go...
# 4405        6824  Paintings 'almost no one else seemed to be doing'
# 4885        9751  An Open Letter to Black South African Police O...
# 4971        2906      US faces calls to ‘walk away’ from Iran talks
# ...

# %%
#should i do this?


#df = df_dataset_1.drop_duplicates(subset=['title', 'text'])

# %%
df_dataset_1 = df_dataset_1.drop('Unnamed: 0', axis=1)

df_dataset_1.head()
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL
