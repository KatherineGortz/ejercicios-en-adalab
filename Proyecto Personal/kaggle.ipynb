# %%
#pip install kaggle

# %%
from kaggle.api.kaggle_api_extended import KaggleApi

import os
print(os.path.exists(os.path.expanduser("~/kaggle.json")))  #if false, it can't find the authentication key.
os.environ["KAGGLE_CONFIG_DIR"] = "C:\\Users\\Kathe\\.kaggle"
import pandas as pd

api = KaggleApi()
api.authenticate()
# Out:
# False

# %%
#to see datasets on Kaggle with keyword Fake News

datasets = api.datasets_list(search="Fake News")
print(datasets)
# Out:
# [{'subtitleNullable': 'Fake News dataset based on FakeNewsNet.', 'creatorNameNullable': 'Aleksei Golovin', 'creatorUrlNullable': 'algord', 'totalBytesNullable': 1760511, 'urlNullable': 'https://www.kaggle.com/datasets/algord/fake-news', 'licenseNameNullable': 'CC0: Public Domain', 'descriptionNullable': None, 'ownerNameNullable': 'Aleksei Golovin', 'ownerRefNullable': 'algord', 'titleNullable': 'Fake News', 'currentVersionNumberNullable': 1, 'usabilityRatingNullable': 1.0, 'id': 2623949, 'ref': 'algord/fake-news', 'subtitle': 'Fake News dataset based on FakeNewsNet.', 'hasSubtitle': True, 'creatorName': 'Aleksei Golovin', 'hasCreatorName': True, 'creatorUrl': 'algord', 'hasCreatorUrl': True, 'totalBytes': 1760511, 'hasTotalBytes': True, 'url': 'https://www.kaggle.com/datasets/algord/fake-news', 'hasUrl': True, 'lastUpdated': '2022-11-10T17:31:41.053Z', 'downloadCount': 6762, 'isPrivate': False, 'isFeatured': False, 'licenseName': 'CC0: Public Domain', 'hasLicenseName': True, 'descrip
# ...

# %%
len(datasets) #to see how many lists came up in my search
# Out:
# 20

# %%
df_datasets = pd.DataFrame(datasets)
pd.set_option('display.max_columns', None)

# %%
df_datasets.rename(columns={'ref': 'slug'}, inplace=True) #this is the column I need to reference for downloading datasets
print(df_datasets.columns.get_loc('slug')) #column indexfor slug value

df_datasets #to better visualize the results of the search in Kaggle
# Out:
# 13
#                                      subtitleNullable creatorNameNullable  \
# 0             Fake News dataset based on FakeNewsNet.     Aleksei Golovin
# 1         Fake News Classification on WELFake Dataset     Saurabh Shahane
# 2   Fake news detection is a process that involves...     Bhavik Jikadara
# 3             Balanced dataset for fake news analysis         Hassan Amin
# 4    A Comprehensive Dataset for Fake News Detection          Aadya Singh
# 5         classification of football data (fake,real)     shawky El-gendy
# 6   Text & metadata from fake & biased news source...          Meg Risdal
# 7           Classification of news by type and labels        Ruchi Bhatia
# 8                           Real Or Fake News Dataset    Jillani SoftTech
# 9   Dataset is having records of real and fake new...         Rajat Kumar
# 10  ISOT Fake News detection dataset (binary text ...     clmentbisaillon
# 11  The Battle Against Misinformation: A Text Clas...       Vishakh Patel
# ...

# %%
# Specify the dataset slug (use the slug from the URL)
dataset_slug = 'dataset-owner/dataset-name'
download_path = r'C:\Users\Kathe\Documents\source_code\ejercicios-en-adalab\Proyecto Personal'

def get_datasets(dataset_slug):
    try:
        api.dataset_download_files(dataset_slug, path=download_path, unzip=True)
        print(f"Dataset downloaded and extracted to {download_path}")

    except Exception as e:
        print(f"Error downloading dataset: {e}")

# %%
#Real Or Fake News Dataset ROW INDEX 8 ibn dataframe

Dataset1 = get_datasets(df_datasets.iloc[8, 13])
# Out:
# Dataset URL: https://www.kaggle.com/datasets/jillanisofttech/fake-or-real-news
# Dataset downloaded and extracted to C:\Users\Kathe\Documents\source_code\ejercicios-en-adalab\Proyecto Personal

# %%
Dataset2= get_datasets(df_datasets.iloc[11, 13])
# Out:
# Dataset URL: https://www.kaggle.com/datasets/vishakhdapat/fake-news-detection
# Dataset downloaded and extracted to C:\Users\Kathe\Documents\source_code\ejercicios-en-adalab\Proyecto Personal

# %%
Dataset3 = get_datasets(df_datasets.iloc[4, 13])

print(df_datasets.iloc[4, 0])
# Out:
# Dataset URL: https://www.kaggle.com/datasets/aadyasingh55/fake-news-classification
# Dataset downloaded and extracted to C:\Users\Kathe\Documents\source_code\ejercicios-en-adalab\Proyecto Personal
# A Comprehensive Dataset for Fake News Detection

# %%
Dataset4 = get_datasets(df_datasets.iloc[10, 13])
# Out:
# Dataset URL: https://www.kaggle.com/datasets/clmentbisaillon/fake-and-real-news-dataset
# Dataset downloaded and extracted to C:\Users\Kathe\Documents\source_code\ejercicios-en-adalab\Proyecto Personal

# %%
Dataset5 = get_datasets(df_datasets.iloc[12, 13])
# Out:
# Dataset URL: https://www.kaggle.com/datasets/jruvika/fake-news-detection
# Dataset downloaded and extracted to C:\Users\Kathe\Documents\source_code\ejercicios-en-adalab\Proyecto Personal

# %%
Dataset6 = get_datasets(df_datasets.iloc[13, 13])
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mohamadalhasan/a-fake-news-dataset-around-the-syrian-war
# Dataset downloaded and extracted to C:\Users\Kathe\Documents\source_code\ejercicios-en-adalab\Proyecto Personal

# %%
Dataset7 = get_datasets(df_datasets.iloc[17, 13])
# Out:
# Dataset URL: https://www.kaggle.com/datasets/abhinavkrjha/fake-news-challenge
# Dataset downloaded and extracted to C:\Users\Kathe\Documents\source_code\ejercicios-en-adalab\Proyecto Personal

# %%
Dataset8 = get_datasets(df_datasets.iloc[18, 13])
# Out:
# Dataset URL: https://www.kaggle.com/datasets/saratchendra/fake-news
# Dataset downloaded and extracted to C:\Users\Kathe\Documents\source_code\ejercicios-en-adalab\Proyecto Personal

# %%
# Out:
#       Unnamed: 0                                              title  \
# 0           8476                       You Can Smell Hillary’s Fear
# 1          10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2           3608        Kerry to go to Paris in gesture of sympathy
# 3          10142  Bernie supporters on Twitter erupt in anger ag...
# 4            875   The Battle of New York: Why This Primary Matters
# ...          ...                                                ...
# 6330        4490  State Department says it can't find emails fro...
# 6331        8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332        8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333        4021  In Ethiopia, Obama seeks progress on peace, se...
# 6334        4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# ...
