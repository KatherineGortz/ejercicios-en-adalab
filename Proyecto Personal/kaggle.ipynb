# %%
pip install kaggle
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for kaggle: filename=kaggle-1.6.17-py3-none-any.whl size=105854 sha256=a3956b2ad2ff133fc7f8c174c894629b6f6a0e5281bf7f93480dbac44ea94f02
#   Stored in directory: c:\users\kathe\appdata\local\pip\cache\wheels\93\6e\87\6d3385c22c1284be8161dfa643c4a58009b8ee4f0ea9ca54ff
# Successfully built kaggle
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from kaggle.api.kaggle_api_extended import KaggleApi

# %%
datasets = api.datasets_list(search="fake news")

# %%
len(datasets)
# Out:
# 20

# %%
FakeNewsAMT = api.datasets_list(search="FakeNewsAMT")

# %%
FakeNewsAMT
# Out:
# [{'subtitleNullable': 'Two fake news datasets covering seven different news domains. ',
#   'creatorNameNullable': 'sumanthvrao',
#   'creatorUrlNullable': 'sumanthvrao',
#   'totalBytesNullable': 2723918,
#   'urlNullable': 'https://www.kaggle.com/datasets/sumanthvrao/fakenewsdataset',
#   'licenseNameNullable': 'Unknown',
#   'descriptionNullable': None,
#   'ownerNameNullable': 'sumanthvrao',
#   'ownerRefNullable': 'sumanthvrao',
#   'titleNullable': 'Fake-News-Dataset',
#   'currentVersionNumberNullable': 3,
#   'usabilityRatingNullable': 0.5294118,
#   'id': 169457,
#   'ref': 'sumanthvrao/fakenewsdataset',
#   'subtitle': 'Two fake news datasets covering seven different news domains. ',
#   'hasSubtitle': True,
#   'creatorName': 'sumanthvrao',
#   'hasCreatorName': True,
#   'creatorUrl': 'sumanthvrao',
#   'hasCreatorUrl': True,
#   'totalBytes': 2723918,
#   'hasTotalBytes': True,
#   'url': 'https://www.kaggle.com/datasets/sumanthvrao/fakenewsdataset',
#   'hasUrl': True,
# ...

# %%
# Initialize the Kaggle API
api = KaggleApi()
api.authenticate()

# Download the dataset (use the dataset slug)
api.dataset_download_files('sumanthvrao/fakenewsdataset', path=r'C:\Users\Kathe\Documents\source_code\ejercicios-en-adalab\Proyecto Personal', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sumanthvrao/fakenewsdataset

# %%
from kaggle.api.kaggle_api_extended import KaggleApi

# Initialize the Kaggle API
api = KaggleApi()
api.authenticate()

# Specify the dataset slug (use the slug from the URL)
dataset_slug = 'sumanthvrao/fakenewsdataset'

# Specify the download directory
download_path = r'C:\Users\Kathe\Documents\source_code\ejercicios-en-adalab\Proyecto Personal'

# Download and unzip the dataset
api.dataset_download_files(dataset_slug, path=download_path, unzip=True)

print(f"Dataset downloaded and extracted to {download_path}")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sumanthvrao/fakenewsdataset
# Dataset downloaded and extracted to C:\Users\Kathe\Documents\source_code\ejercicios-en-adalab\Proyecto Personal

# %%
FakeNewsFNC = api.datasets_list(search="FNC-1")

# %%
FakeNewsFNC
# Out:
# [{'subtitleNullable': '',
#   'creatorNameNullable': 'Hồng Anh Trần',
#   'creatorUrlNullable': 'hnganhtrn',
#   'totalBytesNullable': 7189878,
#   'urlNullable': 'https://www.kaggle.com/datasets/hnganhtrn/fnc-1-fakenews',
#   'licenseNameNullable': 'Apache 2.0',
#   'descriptionNullable': None,
#   'ownerNameNullable': 'Hồng Anh Trần',
#   'ownerRefNullable': 'hnganhtrn',
#   'titleNullable': 'FNC-1 FakeNews',
#   'currentVersionNumberNullable': 1,
#   'usabilityRatingNullable': 0.3529412,
#   'id': 5222584,
#   'ref': 'hnganhtrn/fnc-1-fakenews',
#   'subtitle': '',
#   'hasSubtitle': True,
#   'creatorName': 'Hồng Anh Trần',
#   'hasCreatorName': True,
#   'creatorUrl': 'hnganhtrn',
#   'hasCreatorUrl': True,
#   'totalBytes': 7189878,
#   'hasTotalBytes': True,
#   'url': 'https://www.kaggle.com/datasets/hnganhtrn/fnc-1-fakenews',
#   'hasUrl': True,
#   'lastUpdated': '2024-06-16T18:04:45.43Z',
#   'downloadCount': 12,
#   'isPrivate': False,
#   'isFeatured': False,
# ...

# %%
dataset_slug_fnc = 'hnganhtrn/fnc-1-fakenews'

# Specify the download directory
download_path = r'C:\Users\Kathe\Documents\source_code\ejercicios-en-adalab\Proyecto Personal'

# Download and unzip the dataset
api.dataset_download_files(dataset_slug_fnc, path=download_path, unzip=True)

print(f"Dataset downloaded and extracted to {download_path}")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/hnganhtrn/fnc-1-fakenews
# Dataset downloaded and extracted to C:\Users\Kathe\Documents\source_code\ejercicios-en-adalab\Proyecto Personal
