# %%
import mysql.connector
from mysql.connector import Error

import pandas as pd

# %%
def getConnection():
    try:
        cnx = mysql.connector.connect (user= "root", password= 'AlumnaAdalab', host='127.0,0.1' , database = 'northwind')
        print ("conexion exitosa")
    except mysql.connector.Error as err:
        print("Error al conectar con MYSQL: {err}")

# %%
getConnection()
# Out:
# Error al conectar con MYSQL: {err}

# %%
#1. establish connection with try/except

try:
  cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database = 'northwind')

except mysql.connector.Error as err:


  if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
    print("Something is wrong with your user name or password")
  
  # si el error no tiene que ver con la contraseña, puede ser porque la base de datos no exista, devuelveme un mensaje de que la base de datos no existe
  elif err.errno == errorcode.ER_BAD_DB_ERROR:
    print("Database does not exist")
  
  # si no es por ninguno de los errores anteriores, printeame cual es el error que estoy teniendo en mi conexión
  else:
    print(err)

# %%
if cnx.is_connected():
    print("Connection to MySQL is successful!")
else:
    print("Connection failed.")
# Out:
# Connection to MySQL is successful!

# %%
#Usando "information_schema" en la conexión a base de datos, extraer los nombres de las columnas de la tabla "customers" de la BBDD "northwind".
mycursor = cnx.cursor()
queryColumns = "SELECT * FROM INFORMATION_SCHEMA.COLUMNS WHERE table_name = 'customers'"
result = mycursor.execute(queryColumns)
result = mycursor.fetchall()
print(result)
cnx.close()
# Out:
# [('def', 'northwind', 'customers', 'Address', 5, None, 'YES', 'varchar', 60, 240, None, None, None, 'utf8mb4', 'utf8mb4_0900_ai_ci', 'varchar(60)', '', '', 'select,insert,update,references', '', '', None), ('def', 'northwind', 'customers', 'City', 6, None, 'YES', 'varchar', 15, 60, None, None, None, 'utf8mb4', 'utf8mb4_0900_ai_ci', 'varchar(15)', 'MUL', '', 'select,insert,update,references', '', '', None), ('def', 'northwind', 'customers', 'CompanyName', 2, None, 'NO', 'varchar', 40, 160, None, None, None, 'utf8mb4', 'utf8mb4_0900_ai_ci', 'varchar(40)', 'MUL', '', 'select,insert,update,references', '', '', None), ('def', 'northwind', 'customers', 'ContactName', 3, None, 'YES', 'varchar', 30, 120, None, None, None, 'utf8mb4', 'utf8mb4_0900_ai_ci', 'varchar(30)', '', '', 'select,insert,update,references', '', '', None), ('def', 'northwind', 'customers', 'ContactTitle', 4, None, 'YES', 'varchar', 30, 120, None, None, None, 'utf8mb4', 'utf8mb4_0900_ai_ci', 'varchar(30)', '', '', 'select,
# ...

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database = 'northwind')

# %%
mycursor = cnx.cursor()
queryCity = "SELECT * FROM customers WHERE city ='London' OR 'Seattle'"
result = mycursor.execute(queryCity)
result = mycursor.fetchall()
#print(result)
for x in result:
    print(x)
# Out:
# ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', None, 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750')
# ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Sales Representative', 'Fauntleroy Circus', 'London', None, 'EC2 5NT', 'UK', '(171) 555-1212', None)
# ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Sales Representative', 'Berkeley Gardens 12  Brewery', 'London', None, 'WX1 6LT', 'UK', '(171) 555-2282', '(171) 555-9199')
# ('EASTC', 'Eastern Connection', 'Ann Devon', 'Sales Agent', '35 King George', 'London', None, 'WX3 6FW', 'UK', '(171) 555-0297', '(171) 555-3373')
# ('NORTS', 'North/South', 'Simon Crowther', 'Sales Associate', 'South House 300 Queensbridge', 'London', None, 'SW7 1RZ', 'UK', '(171) 555-7733', '(171) 555-2530')
# ('SEVES', 'Seven Seas Imports', 'Hari Kumar', 'Sales Manager', '90 Wadhurst Rd.', 'London', None, 'OX15 4NB', 'UK', '(171) 555-1717', '(171) 555-5646')

# %%
df = pd.DataFrame(result, columns = [ 'CustomerID',
                                    'CompanyName',
                                    'ContactName',
                                    'ContactTitle',
                                    'Address',
                                    'City',
                                    'Region',
                                    'PostalCode',
                                    'Country',
                                    'Phone',
                                    'Fax',]
                                    )

# %%
df
# Out:
#   CustomerID            CompanyName        ContactName          ContactTitle  \
# 0      AROUT        Around the Horn       Thomas Hardy  Sales Representative
# 1      BSBEV          B's Beverages  Victoria Ashworth  Sales Representative
# 2      CONSH  Consolidated Holdings    Elizabeth Brown  Sales Representative
# 3      EASTC     Eastern Connection          Ann Devon           Sales Agent
# 4      NORTS            North/South     Simon Crowther       Sales Associate
# 5      SEVES     Seven Seas Imports         Hari Kumar         Sales Manager
#
#                         Address    City Region PostalCode Country  \
# 0               120 Hanover Sq.  London   None    WA1 1DP      UK
# 1             Fauntleroy Circus  London   None    EC2 5NT      UK
# 2  Berkeley Gardens 12  Brewery  London   None    WX1 6LT      UK
# 3                35 King George  London   None    WX3 6FW      UK
# 4  South House 300 Queensbridge  London   None    SW7 1RZ      UK
# ...

# %%
#Muestra las 10 primeras filas del Dataframe y las 10 últimas.
df.head(10)
# Out:
#   CustomerID            CompanyName        ContactName          ContactTitle  \
# 0      AROUT        Around the Horn       Thomas Hardy  Sales Representative
# 1      BSBEV          B's Beverages  Victoria Ashworth  Sales Representative
# 2      CONSH  Consolidated Holdings    Elizabeth Brown  Sales Representative
# 3      EASTC     Eastern Connection          Ann Devon           Sales Agent
# 4      NORTS            North/South     Simon Crowther       Sales Associate
# 5      SEVES     Seven Seas Imports         Hari Kumar         Sales Manager
#
#                         Address    City Region PostalCode Country  \
# 0               120 Hanover Sq.  London   None    WA1 1DP      UK
# 1             Fauntleroy Circus  London   None    EC2 5NT      UK
# 2  Berkeley Gardens 12  Brewery  London   None    WX1 6LT      UK
# 3                35 King George  London   None    WX3 6FW      UK
# 4  South House 300 Queensbridge  London   None    SW7 1RZ      UK
# ...

# %%
df.tail(10)
# Out:
#   CustomerID            CompanyName        ContactName          ContactTitle  \
# 0      AROUT        Around the Horn       Thomas Hardy  Sales Representative
# 1      BSBEV          B's Beverages  Victoria Ashworth  Sales Representative
# 2      CONSH  Consolidated Holdings    Elizabeth Brown  Sales Representative
# 3      EASTC     Eastern Connection          Ann Devon           Sales Agent
# 4      NORTS            North/South     Simon Crowther       Sales Associate
# 5      SEVES     Seven Seas Imports         Hari Kumar         Sales Manager
#
#                         Address    City Region PostalCode Country  \
# 0               120 Hanover Sq.  London   None    WA1 1DP      UK
# 1             Fauntleroy Circus  London   None    EC2 5NT      UK
# 2  Berkeley Gardens 12  Brewery  London   None    WX1 6LT      UK
# 3                35 King George  London   None    WX3 6FW      UK
# 4  South House 300 Queensbridge  London   None    SW7 1RZ      UK
# ...

# %%
#Mostrar 5 filas aleatorias del Dataframe.
df.sample(5)
# Out:
#   CustomerID         CompanyName        ContactName          ContactTitle  \
# 1      BSBEV       B's Beverages  Victoria Ashworth  Sales Representative
# 0      AROUT     Around the Horn       Thomas Hardy  Sales Representative
# 5      SEVES  Seven Seas Imports         Hari Kumar         Sales Manager
# 4      NORTS         North/South     Simon Crowther       Sales Associate
# 3      EASTC  Eastern Connection          Ann Devon           Sales Agent
#
#                         Address    City Region PostalCode Country  \
# 1             Fauntleroy Circus  London   None    EC2 5NT      UK
# 0               120 Hanover Sq.  London   None    WA1 1DP      UK
# 5               90 Wadhurst Rd.  London   None   OX15 4NB      UK
# 4  South House 300 Queensbridge  London   None    SW7 1RZ      UK
# 3                35 King George  London   None    WX3 6FW      UK
#
#             Phone             Fax
# 1  (171) 555-1212            None
# 0  (171) 555-7788  (171) 555-6750
# ...

# %%
#¿Hay nulos en el Dataframe? El resultado debe verse para cada una de las columnas.

df.isnull()
# Out:
#    CustomerID  CompanyName  ContactName  ContactTitle  Address   City  Region  \
# 0       False        False        False         False    False  False    True
# 1       False        False        False         False    False  False    True
# 2       False        False        False         False    False  False    True
# 3       False        False        False         False    False  False    True
# 4       False        False        False         False    False  False    True
# 5       False        False        False         False    False  False    True
#
#    PostalCode  Country  Phone    Fax
# 0       False    False  False  False
# 1       False    False  False   True
# 2       False    False  False  False
# 3       False    False  False  False
# 4       False    False  False  False
# 5       False    False  False  False

# %%
#Mostrar los principales estadísticos.

df.describe()
# Out:
#        CustomerID      CompanyName   ContactName          ContactTitle  \
# count           6                6             6                     6
# unique          6                6             6                     4
# top         AROUT  Around the Horn  Thomas Hardy  Sales Representative
# freq            1                1             1                     3
#
#                 Address    City Region PostalCode Country           Phone  \
# count                 6       6      0          6       6               6
# unique                6       1      0          6       1               6
# top     120 Hanover Sq.  London    NaN    WA1 1DP      UK  (171) 555-7788
# freq                  1       6    NaN          1       6               1
#
#                    Fax
# count                5
# unique               5
# top     (171) 555-6750
# freq                 1

# %%
#Mostrar el nombre de las columnas del Dataframe.

print(df.columns)
# Out:
# Index(['CustomerID', 'CompanyName', 'ContactName', 'ContactTitle', 'Address',
#        'City', 'Region', 'PostalCode', 'Country', 'Phone', 'Fax'],
#       dtype='object')
